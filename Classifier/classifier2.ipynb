# %%
import os
import pandas as pd
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models
import matplotlib.pyplot as plt
from tqdm import tqdm

import numpy as np
import cv2
from torchvision import models
import torch.nn.functional as F

# %%
# 1. Уменьшение больших .txt файлов
# ============================================================
def reduce_txt(input_txt, output_txt, max_rows):
    """
    Уменьшает количество строк в .txt файле до max_rows
    с сохранением пропорций классов.
    """
    df = pd.read_csv(
        input_txt,
        sep=" ", header=None,
        names=["filename", "class", "xmin", "ymin", "xmax", "ymax"]
    )

    if len(df) <= max_rows:
        df.to_csv(output_txt, sep=" ", header=False, index=False)
        print(f"{input_txt}: строк {len(df)}, сохранили без изменений.")
        return

    df_small = df.groupby("class", group_keys=False).apply(
        lambda x: x.sample(frac=min(1.0, max_rows/len(df)), random_state=42)
    )
    df_small = df_small.sample(frac=1, random_state=42).reset_index(drop=True)

    df_small.to_csv(output_txt, sep=" ", header=False, index=False)
    print(f"{input_txt}: уменьшено {len(df)} → {len(df_small)}, сохранено {output_txt}")

# %%
# 2. Трансформации
# ============================================================
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

val_test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
# 3. Класс датасета
# ============================================================
class CovidCTDataset(Dataset):
    def __init__(self, txt_file, img_dir, transform=None, use_crop=False):
        self.df = pd.read_csv(
            txt_file, sep=" ", header=None,
            names=["filename", "class", "xmin", "ymin", "xmax", "ymax"]
        )
        self.img_dir = img_dir
        self.transform = transform
        self.use_crop = use_crop

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_path = os.path.join(self.img_dir, row["filename"])
        image = Image.open(img_path).convert("RGB")
        label = int(row["class"])

        if self.use_crop:
            xmin, ymin, xmax, ymax = row[["xmin", "ymin", "xmax", "ymax"]]
            image = image.crop((xmin, ymin, xmax, ymax))

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
# 4. DataLoader
# ============================================================
def get_dataloaders(train_file, val_file, test_file, img_dir, batch_size=32):
    train_ds = CovidCTDataset(train_file, img_dir, transform=train_transform)
    val_ds   = CovidCTDataset(val_file, img_dir, transform=val_test_transform)
    test_ds  = CovidCTDataset(test_file, img_dir, transform=val_test_transform)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=0)
    val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=0)

    return train_loader, val_loader, test_loader

# %%
# 5. Модель DenseNet121
# ============================================================
def get_model(num_classes=3):
    model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
    in_f = model.classifier.in_features
    model.classifier = nn.Linear(in_f, num_classes)
    return model

# %%
# 6. Циклы обучения и теста
# ============================================================
def train_one_epoch(model, loader, criterion, optimizer, device, epoch, total_epochs):
    model.train()
    running_loss, correct, total = 0.0, 0, 0

    pbar = tqdm(loader, desc=f"Epoch [{epoch}/{total_epochs}] Training", unit="batch")
    for inputs, labels in pbar:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

        pbar.set_postfix(loss=running_loss/total, acc=100*correct/total)

    return float(running_loss/total), float(correct/total)

# %%
def evaluate(model, loader, criterion, device, phase="Val"):
    model.eval()
    running_loss, correct, total = 0.0, 0, 0

    with torch.no_grad():
        for inputs, labels in tqdm(loader, desc=f"{phase} evaluating", unit="batch"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    return float(running_loss/total), float(correct/total)

# %%
# Устройство
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Используемое устройство: {device}")
# Out:
# Используемое устройство: cuda

# %%
history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": [], "test_loss": [], "test_acc": []}

# %%
# 7. Основной блок
# ============================================================
# Уменьшаем файлы (если нужно)
reduce_txt("dataset2/train_COVIDx_CT-3A.txt", "train_small.txt", 50000)
reduce_txt("dataset2/val_COVIDx_CT-3A.txt", "val_small.txt", 5000)
reduce_txt("dataset2/test_COVIDx_CT-3A.txt", "test_small.txt", 5000)

img_dir = "dataset2/3A_images"  # путь к папке с картинками
train_file, val_file, test_file = "train_small.txt", "val_small.txt", "test_small.txt"

# DataLoader
train_loader, val_loader, test_loader = get_dataloaders(train_file, val_file, test_file, img_dir, batch_size=16)

# Модель
model = get_model(num_classes=3).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# Обучение
num_epochs = 20

for epoch in range(1, num_epochs+1):
    train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device, epoch, num_epochs)
    val_loss, val_acc = evaluate(model, val_loader, criterion, device, phase="Val")
    test_loss, test_acc = evaluate(model, test_loader, criterion, device, phase="Test")

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)
    history["test_loss"].append(test_loss)
    history["test_acc"].append(test_acc)

    print(f"Epoch {epoch}/{num_epochs} -> "
            f"Train acc: {train_acc:.2f}, Val acc: {val_acc:.2f}, Test acc: {test_acc:.2f}")
    torch.cuda.empty_cache()
    
best_model_path = "best_densenet_ct.pth"
torch.save(model.state_dict(), best_model_path)
print(f"Модель сохранена в {best_model_path}")
# Out:
# C:\Users\denvd\AppData\Local\Temp\ipykernel_8648\406885135.py:19: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_small = df.groupby("class", group_keys=False).apply(
# C:\Users\denvd\AppData\Local\Temp\ipykernel_8648\406885135.py:19: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_small = df.groupby("class", group_keys=False).apply(
# dataset2/train_COVIDx_CT-3A.txt: уменьшено 357518 → 50000, сохранено train_small.txt
# dataset2/val_COVIDx_CT-3A.txt: уменьшено 33725 → 5000, сохранено val_small.txt
# dataset2/test_COVIDx_CT-3A.txt: уменьшено 33781 → 5000, сохранено test_small.txt
# C:\Users\denvd\AppData\Local\Temp\ipykernel_8648\406885135.py:19: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_small = df.groupby("class", group_keys=False).apply(
# Epoch [1/20] Training: 100%|██████████| 3125/3125 [16:12<00:00,  3.21batch/s, acc=97.5, loss=0.0769]
# Val evaluating: 100%|██████████| 313/313 [01:05<00:00,  4.79batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:55<00:00,  5.64batch/s]
# Epoch 1/20 -> Train acc: 0.97, Val acc: 0.92, Test acc: 0.93
# Epoch [2/20] Training: 100%|██████████| 3125/3125 [13:34<00:00,  3.84batch/s, acc=98.9, loss=0.0323]
# Val evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.11batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.04batch/s]
# Epoch 2/20 -> Train acc: 0.99, Val acc: 0.90, Test acc: 0.91
# Epoch [3/20] Training: 100%|██████████| 3125/3125 [12:21<00:00,  4.21batch/s, acc=99.2, loss=0.0235]
# Val evaluating: 100%|██████████| 313/313 [00:36<00:00,  8.61batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.02batch/s]
# Epoch 3/20 -> Train acc: 0.99, Val acc: 0.94, Test acc: 0.95
# Epoch [4/20] Training: 100%|██████████| 3125/3125 [07:46<00:00,  6.70batch/s, acc=99.3, loss=0.0202]
# Val evaluating: 100%|██████████| 313/313 [00:33<00:00,  9.26batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:35<00:00,  8.93batch/s]
# Epoch 4/20 -> Train acc: 0.99, Val acc: 0.93, Test acc: 0.94
# Epoch [5/20] Training: 100%|██████████| 3125/3125 [07:43<00:00,  6.74batch/s, acc=99.4, loss=0.0179]
# Val evaluating: 100%|██████████| 313/313 [00:33<00:00,  9.43batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.12batch/s]
# Epoch 5/20 -> Train acc: 0.99, Val acc: 0.93, Test acc: 0.94
# Epoch [6/20] Training: 100%|██████████| 3125/3125 [15:04<00:00,  3.46batch/s, acc=99.5, loss=0.0134]
# Val evaluating: 100%|██████████| 313/313 [00:45<00:00,  6.95batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:43<00:00,  7.17batch/s]
# Epoch 6/20 -> Train acc: 1.00, Val acc: 0.95, Test acc: 0.96
# Epoch [7/20] Training: 100%|██████████| 3125/3125 [17:41<00:00,  2.94batch/s, acc=99.6, loss=0.0123]
# Val evaluating: 100%|██████████| 313/313 [00:38<00:00,  8.23batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.07batch/s]
# Epoch 7/20 -> Train acc: 1.00, Val acc: 0.92, Test acc: 0.92
# Epoch [8/20] Training: 100%|██████████| 3125/3125 [20:25<00:00,  2.55batch/s, acc=99.7, loss=0.0106]
# Val evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.18batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  8.99batch/s]
# Epoch 8/20 -> Train acc: 1.00, Val acc: 0.89, Test acc: 0.89
# Epoch [9/20] Training: 100%|██████████| 3125/3125 [09:02<00:00,  5.76batch/s, acc=99.7, loss=0.0107]
# Val evaluating: 100%|██████████| 313/313 [00:35<00:00,  8.78batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.10batch/s]
# Epoch 9/20 -> Train acc: 1.00, Val acc: 0.95, Test acc: 0.95
# Epoch [10/20] Training: 100%|██████████| 3125/3125 [14:22<00:00,  3.62batch/s, acc=99.7, loss=0.00828]
# Val evaluating: 100%|██████████| 313/313 [01:11<00:00,  4.38batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:46<00:00,  6.71batch/s]
# Epoch 10/20 -> Train acc: 1.00, Val acc: 0.93, Test acc: 0.94
# Epoch [11/20] Training: 100%|██████████| 3125/3125 [15:09<00:00,  3.44batch/s, acc=99.7, loss=0.00895]
# Val evaluating: 100%|██████████| 313/313 [00:35<00:00,  8.82batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.03batch/s]
# Epoch 11/20 -> Train acc: 1.00, Val acc: 0.90, Test acc: 0.90
# Epoch [12/20] Training: 100%|██████████| 3125/3125 [11:36<00:00,  4.49batch/s, acc=99.8, loss=0.00661]
# Val evaluating: 100%|██████████| 313/313 [00:34<00:00,  8.97batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  8.97batch/s]
# Epoch 12/20 -> Train acc: 1.00, Val acc: 0.89, Test acc: 0.89
# Epoch [13/20] Training: 100%|██████████| 3125/3125 [09:17<00:00,  5.60batch/s, acc=99.7, loss=0.00742]
# Val evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.00batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:35<00:00,  8.91batch/s]
# Epoch 13/20 -> Train acc: 1.00, Val acc: 0.93, Test acc: 0.94
# Epoch [14/20] Training: 100%|██████████| 3125/3125 [11:29<00:00,  4.53batch/s, acc=99.8, loss=0.00679]
# Val evaluating: 100%|██████████| 313/313 [00:52<00:00,  6.00batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:52<00:00,  5.96batch/s]
# Epoch 14/20 -> Train acc: 1.00, Val acc: 0.92, Test acc: 0.91
# Epoch [15/20] Training: 100%|██████████| 3125/3125 [17:14<00:00,  3.02batch/s, acc=99.8, loss=0.00606]
# Val evaluating: 100%|██████████| 313/313 [00:53<00:00,  5.82batch/s]
# Test evaluating: 100%|██████████| 313/313 [01:02<00:00,  5.01batch/s]
# Epoch 15/20 -> Train acc: 1.00, Val acc: 0.92, Test acc: 0.92
# Epoch [16/20] Training: 100%|██████████| 3125/3125 [17:39<00:00,  2.95batch/s, acc=99.8, loss=0.00599]
# Val evaluating: 100%|██████████| 313/313 [00:36<00:00,  8.53batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.04batch/s]
# Epoch 16/20 -> Train acc: 1.00, Val acc: 0.82, Test acc: 0.83
# Epoch [17/20] Training: 100%|██████████| 3125/3125 [14:15<00:00,  3.65batch/s, acc=99.8, loss=0.00607]
# Val evaluating: 100%|██████████| 313/313 [00:35<00:00,  8.79batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.02batch/s]
# Epoch 17/20 -> Train acc: 1.00, Val acc: 0.93, Test acc: 0.93
# Epoch [18/20] Training: 100%|██████████| 3125/3125 [09:32<00:00,  5.46batch/s, acc=99.8, loss=0.00645]
# Val evaluating: 100%|██████████| 313/313 [00:33<00:00,  9.24batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.05batch/s]
# Epoch 18/20 -> Train acc: 1.00, Val acc: 0.92, Test acc: 0.92
# Epoch [19/20] Training: 100%|██████████| 3125/3125 [12:08<00:00,  4.29batch/s, acc=99.8, loss=0.0048]
# Val evaluating: 100%|██████████| 313/313 [00:36<00:00,  8.64batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:34<00:00,  9.12batch/s]
# Epoch 19/20 -> Train acc: 1.00, Val acc: 0.90, Test acc: 0.89
# Epoch [20/20] Training: 100%|██████████| 3125/3125 [16:05<00:00,  3.24batch/s, acc=99.8, loss=0.00533]
# Val evaluating: 100%|██████████| 313/313 [01:00<00:00,  5.16batch/s]
# Test evaluating: 100%|██████████| 313/313 [00:54<00:00,  5.74batch/s]
# Epoch 20/20 -> Train acc: 1.00, Val acc: 0.81, Test acc: 0.82
# Модель сохранена в best_densenet_ct.pth
# При выполнении кода в текущей ячейке или предыдущей ячейке ядро аварийно завершило работу.
#
# Проверьте код в ячейках, чтобы определить возможную причину сбоя.
#
# Щелкните <a href='https://aka.ms/vscodeJupyterKernelCrash'>здесь</a>, чтобы получить дополнительные сведения.
#
# Подробнее см. в <a href='command:jupyter.viewOutput'>журнале Jupyter</a>.

# %%
# Графики
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Val Loss")
plt.plot(history["test_loss"], label="Test Loss")
plt.title("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history["train_acc"], label="Train Acc")
plt.plot(history["val_acc"], label="Val Acc")
plt.plot(history["test_acc"], label="Test Acc")
plt.title("Accuracy")
plt.legend()

plt.show()

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
# Классы (под свой датасет)
class_names = ["Normal", "CAP", "COVID-19"]

def get_cam_bbox(cam, threshold=0.5):
    """
    Возвращает координаты прямоугольника по Grad-CAM карте
    threshold: порог выделения активной зоны (0-1)
    """
    mask = cam > threshold
    if not np.any(mask):
        return None  # если модель ничего не выделила

    ys, xs = np.where(mask)
    xmin, xmax = xs.min(), xs.max()
    ymin, ymax = ys.min(), ys.max()
    return (xmin, ymin, xmax, ymax)

def predict_image_with_bbox(model, image_path, device, target_layer="features.denseblock4"):
    img = Image.open(image_path).convert("RGB")
    input_tensor = transform(img).unsqueeze(0).to(device)

    # Сохраняем активации и градиенты
    activations, gradients = {}, {}

    def forward_hook(module, inp, out):
        activations["value"] = out

    def backward_hook(module, grad_in, grad_out):
        gradients["value"] = grad_out[0]

    # Вешаем хуки
    layer = dict([*model.named_modules()])[target_layer]
    fwd_handle = layer.register_forward_hook(forward_hook)
    bwd_handle = layer.register_backward_hook(backward_hook)

    model.eval()
    outputs = model(input_tensor)  # без torch.no_grad()!
    probs = torch.softmax(outputs, dim=1)
    conf, pred = torch.max(probs, 1)

    # Обратный проход для CAM
    model.zero_grad()
    outputs[0, pred.item()].backward()

    grads = gradients["value"].detach()
    acts = activations["value"].detach()
    weights = grads.mean(dim=(2, 3), keepdim=True)
    cam = (weights * acts).sum(dim=1).squeeze()
    cam = F.relu(cam).cpu().numpy()
    cam = cv2.resize(cam, (img.size[0], img.size[1]))
    cam = (cam - cam.min()) / (cam.max() - cam.min() + 1e-9)

    # Координаты прямоугольника
    bbox = get_cam_bbox(cam, threshold=0.5)

    # Снимаем хуки
    fwd_handle.remove()
    bwd_handle.remove()

    # Чистим память
    del input_tensor, outputs, grads, acts
    torch.cuda.empty_cache()

    return class_names[pred.item()], conf.item() * 100, bbox

def predict_folder_with_bbox(model, folder_path, device):
    results = []
    for fname in os.listdir(folder_path):
        if fname.lower().endswith((".png", ".jpg", ".jpeg")):
            path = os.path.join(folder_path, fname)
            label, confidence, bbox = predict_image_with_bbox(model, path, device)
            print(f"{fname}: {label} ({confidence:.2f}%), bbox={bbox}")
            results.append((fname, label, confidence, bbox))
    return results

# %%
model = models.densenet121(weights="IMAGENET1K_V1")
in_f = model.classifier.in_features
model.classifier = nn.Linear(in_f, len(class_names))
model.load_state_dict(torch.load("best_densenet_ct.pth", map_location=device))
model = model.to(device)

# %%
# Прогоняем папку
results = predict_folder_with_bbox(model, "postDICOM", device)
# Out:
# d:\Anaconda\envs\PythonAIPyTorch\Lib\site-packages\torch\nn\modules\module.py:1842: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 1.2.643.5.1.13.13.12.2.77.8252.00120800110906151309051502130401.png: COVID-19 (100.00%), bbox=(np.int64(126), np.int64(248), np.int64(370), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.01001413041305061500030501001512.png: COVID-19 (100.00%), bbox=(np.int64(120), np.int64(339), np.int64(431), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.01040806021000100410130007101215.png: COVID-19 (100.00%), bbox=(np.int64(154), np.int64(213), np.int64(414), np.int64(454))
# 1.2.643.5.1.13.13.12.2.77.8252.01050701051505050715080910060315.png: COVID-19 (100.00%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.01061114150915090104151114140611.png: COVID-19 (83.53%), bbox=(np.int64(0), np.int64(354), np.int64(289), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.01070409071501051008110900111301.png: COVID-19 (99.74%), bbox=(np.int64(90), np.int64(177), np.int64(419), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.01081511090912090508100510010313.png: COVID-19 (99.98%), bbox=(np.int64(92), np.int64(286), np.int64(438), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.01111406070202060212060611151400.png: COVID-19 (99.97%), bbox=(np.int64(128), np.int64(340), np.int64(422), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.02000600121403141010041514060604.png: COVID-19 (99.66%), bbox=(np.int64(121), np.int64(210), np.int64(459), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.02031013050505060713151003081312.png: COVID-19 (99.98%), bbox=(np.int64(90), np.int64(261), np.int64(449), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.02050202130506081409030814130602.png: COVID-19 (100.00%), bbox=(np.int64(0), np.int64(70), np.int64(318), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.02091003130911080409070407110104.png: COVID-19 (99.99%), bbox=(np.int64(115), np.int64(259), np.int64(344), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.02140804031505101508050804091006.png: COVID-19 (99.99%), bbox=(np.int64(112), np.int64(337), np.int64(412), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.02151310111008080914081300051502.png: COVID-19 (99.99%), bbox=(np.int64(120), np.int64(252), np.int64(354), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.03111011051206000008101015150412.png: COVID-19 (99.98%), bbox=(np.int64(83), np.int64(218), np.int64(366), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.04040500050501031006030007131108.png: COVID-19 (89.56%), bbox=(np.int64(0), np.int64(320), np.int64(295), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.04101308040003010112150915141410.png: COVID-19 (99.84%), bbox=(np.int64(58), np.int64(315), np.int64(304), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.04110208020514121309150110121101.png: COVID-19 (100.00%), bbox=(np.int64(115), np.int64(239), np.int64(365), np.int64(474))
# 1.2.643.5.1.13.13.12.2.77.8252.04111004040306030913011415060906.png: COVID-19 (100.00%), bbox=(np.int64(59), np.int64(0), np.int64(511), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.04121504080100040604130010021408.png: COVID-19 (97.99%), bbox=(np.int64(77), np.int64(303), np.int64(434), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.05010407121211031507001105101205.png: COVID-19 (99.70%), bbox=(np.int64(132), np.int64(68), np.int64(459), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.05011111120212141506050014131212.png: COVID-19 (99.76%), bbox=(np.int64(104), np.int64(167), np.int64(398), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.05021503000408060108001104141313.png: COVID-19 (99.98%), bbox=(np.int64(68), np.int64(303), np.int64(511), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.05030004130211081514130614060001.png: COVID-19 (99.79%), bbox=(np.int64(86), np.int64(209), np.int64(368), np.int64(433))
# 1.2.643.5.1.13.13.12.2.77.8252.05070314091414040505021502051007.png: COVID-19 (99.98%), bbox=(np.int64(112), np.int64(338), np.int64(412), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.05071514151313120409070704111210.png: COVID-19 (99.99%), bbox=(np.int64(146), np.int64(240), np.int64(379), np.int64(464))
# 1.2.643.5.1.13.13.12.2.77.8252.05150809061004121506101409021313.png: COVID-19 (100.00%), bbox=(np.int64(91), np.int64(281), np.int64(466), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.06010304090709151201031414120809.png: COVID-19 (99.97%), bbox=(np.int64(119), np.int64(347), np.int64(433), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.06020715031500100602060003150400.png: COVID-19 (99.99%), bbox=(np.int64(109), np.int64(339), np.int64(430), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.07000005100912130007100300040202.png: COVID-19 (99.27%), bbox=(np.int64(117), np.int64(80), np.int64(457), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.07030208011100121312020914000711.png: COVID-19 (99.99%), bbox=(np.int64(120), np.int64(345), np.int64(431), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.07070901121104011400010101040006.png: COVID-19 (99.99%), bbox=(np.int64(95), np.int64(343), np.int64(447), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.07141211120808120105071310090011.png: COVID-19 (99.96%), bbox=(np.int64(61), np.int64(250), np.int64(417), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.08031105091004050714140812000113.png: COVID-19 (95.74%), bbox=(np.int64(123), np.int64(138), np.int64(454), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.08090407140314011412111504031510.png: COVID-19 (99.99%), bbox=(np.int64(105), np.int64(0), np.int64(393), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.08110200101306010201000607141206.png: COVID-19 (99.56%), bbox=(np.int64(129), np.int64(248), np.int64(351), np.int64(474))
# 1.2.643.5.1.13.13.12.2.77.8252.08120307010003020310010407100514.png: COVID-19 (100.00%), bbox=(np.int64(52), np.int64(0), np.int64(511), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.09020212061100050015140411130511.png: COVID-19 (99.98%), bbox=(np.int64(78), np.int64(221), np.int64(378), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.09091203050612070705100306130001.png: COVID-19 (100.00%), bbox=(np.int64(90), np.int64(0), np.int64(450), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.09111404020506140002040203070500.png: COVID-19 (99.51%), bbox=(np.int64(109), np.int64(254), np.int64(359), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.09131302010601061008070302091406.png: COVID-19 (100.00%), bbox=(np.int64(113), np.int64(240), np.int64(367), np.int64(474))
# 1.2.643.5.1.13.13.12.2.77.8252.09141002060001080212090812040512.png: COVID-19 (99.98%), bbox=(np.int64(112), np.int64(352), np.int64(420), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.10000806100002111215151409051315.png: COVID-19 (100.00%), bbox=(np.int64(103), np.int64(0), np.int64(454), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.10030600091100100704040815031002.png: COVID-19 (100.00%), bbox=(np.int64(0), np.int64(281), np.int64(423), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.10040809140110080304120815131407.png: COVID-19 (97.80%), bbox=(np.int64(122), np.int64(276), np.int64(369), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.10090402000201090501071501100706.png: COVID-19 (99.95%), bbox=(np.int64(64), np.int64(344), np.int64(444), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.10121114030101020004021401141010.png: COVID-19 (99.99%), bbox=(np.int64(76), np.int64(283), np.int64(402), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.10140401080208041007060312100605.png: COVID-19 (99.99%), bbox=(np.int64(145), np.int64(241), np.int64(369), np.int64(467))
# 1.2.643.5.1.13.13.12.2.77.8252.10141105081014070806090602080111.png: COVID-19 (100.00%), bbox=(np.int64(44), np.int64(307), np.int64(363), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.11060715061304050109130111120711.png: COVID-19 (99.97%), bbox=(np.int64(0), np.int64(0), np.int64(332), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.11080607120712050911120314050710.png: COVID-19 (99.95%), bbox=(np.int64(67), np.int64(346), np.int64(443), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.11100801080704141305130314090414.png: COVID-19 (99.95%), bbox=(np.int64(0), np.int64(0), np.int64(312), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.11101200140012120213100309000109.png: COVID-19 (99.69%), bbox=(np.int64(104), np.int64(76), np.int64(456), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.11141104110100021004080106081013.png: COVID-19 (99.99%), bbox=(np.int64(58), np.int64(269), np.int64(470), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.12070307010211141109150506021013.png: COVID-19 (99.78%), bbox=(np.int64(87), np.int64(171), np.int64(414), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.12090405041500090012020210061304.png: COVID-19 (100.00%), bbox=(np.int64(154), np.int64(197), np.int64(435), np.int64(454))
# 1.2.643.5.1.13.13.12.2.77.8252.12130706030110081408120005020815.png: COVID-19 (98.14%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.13031206020512060510000114101412.png: COVID-19 (99.99%), bbox=(np.int64(112), np.int64(255), np.int64(423), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.13060209070203021208001503141101.png: COVID-19 (99.94%), bbox=(np.int64(84), np.int64(289), np.int64(415), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.13071505110800150110041200030514.png: COVID-19 (99.97%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.13151407031403080813011200121208.png: COVID-19 (99.97%), bbox=(np.int64(57), np.int64(342), np.int64(447), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.14020610101311010411130704141311.png: COVID-19 (99.98%), bbox=(np.int64(102), np.int64(255), np.int64(419), np.int64(511))
# 1.2.643.5.1.13.13.12.2.77.8252.14040610130406070910070613141315.png: COVID-19 (99.92%), bbox=(np.int64(107), np.int64(232), np.int64(356), np.int64(465))
# 10000E6B_anon.png: COVID-19 (99.77%), bbox=(np.int64(0), np.int64(177), np.int64(511), np.int64(364))
# 10000E6C_anon.png: COVID-19 (99.70%), bbox=(np.int64(0), np.int64(178), np.int64(511), np.int64(358))
# 10000E6D_anon.png: COVID-19 (99.67%), bbox=(np.int64(0), np.int64(175), np.int64(511), np.int64(361))
# 10000E6E_anon.png: COVID-19 (99.24%), bbox=(np.int64(0), np.int64(174), np.int64(511), np.int64(357))
# 10000E6F_anon.png: COVID-19 (98.77%), bbox=(np.int64(0), np.int64(176), np.int64(511), np.int64(357))
# 10000E70_anon.png: COVID-19 (95.86%), bbox=(np.int64(0), np.int64(179), np.int64(511), np.int64(358))
# 10000E71_anon.png: COVID-19 (92.10%), bbox=(np.int64(0), np.int64(182), np.int64(511), np.int64(359))
# 10000E72_anon.png: COVID-19 (83.03%), bbox=(np.int64(0), np.int64(190), np.int64(511), np.int64(354))
# 10000E73_anon.png: COVID-19 (67.63%), bbox=(np.int64(0), np.int64(188), np.int64(275), np.int64(359))
# 10000E74_anon.png: CAP (51.33%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(219))
# 10000E75_anon.png: CAP (63.48%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(227))
# 10000E76_anon.png: CAP (72.19%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(225))
# 10000E77_anon.png: CAP (76.96%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(224))
# 10000E78_anon.png: CAP (93.25%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(358))
# 10000E79_anon.png: CAP (96.82%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(362))
# 10000E7A_anon.png: CAP (98.67%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(376))
# 10000E7B_anon.png: CAP (99.29%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(391))
# 10000E7C_anon.png: CAP (99.51%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(393))
# 10000E7D_anon.png: CAP (99.83%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(392))
# 10000E7E_anon.png: CAP (99.91%), bbox=(np.int64(90), np.int64(0), np.int64(466), np.int64(391))
# 10000E7F_anon.png: CAP (99.91%), bbox=(np.int64(103), np.int64(0), np.int64(443), np.int64(393))
# 10000E80_anon.png: CAP (99.85%), bbox=(np.int64(97), np.int64(0), np.int64(434), np.int64(395))
# 10000E81_anon.png: CAP (99.77%), bbox=(np.int64(95), np.int64(0), np.int64(431), np.int64(398))
# 10000E82_anon.png: CAP (99.88%), bbox=(np.int64(96), np.int64(0), np.int64(441), np.int64(394))
# 10000E83_anon.png: CAP (99.95%), bbox=(np.int64(147), np.int64(0), np.int64(440), np.int64(393))
# 10000E84_anon.png: CAP (99.93%), bbox=(np.int64(147), np.int64(0), np.int64(440), np.int64(395))
# 10000E85_anon.png: CAP (99.98%), bbox=(np.int64(142), np.int64(142), np.int64(449), np.int64(392))
# 10000E86_anon.png: CAP (99.99%), bbox=(np.int64(135), np.int64(151), np.int64(455), np.int64(392))
# 10000E87_anon.png: CAP (99.98%), bbox=(np.int64(131), np.int64(137), np.int64(449), np.int64(392))
# 10000E88_anon.png: CAP (99.97%), bbox=(np.int64(135), np.int64(152), np.int64(436), np.int64(395))
# 10000E89_anon.png: CAP (99.94%), bbox=(np.int64(130), np.int64(166), np.int64(437), np.int64(403))
# 10000E8A_anon.png: CAP (99.96%), bbox=(np.int64(124), np.int64(194), np.int64(448), np.int64(405))
# 10000E8B_anon.png: CAP (99.93%), bbox=(np.int64(128), np.int64(197), np.int64(456), np.int64(410))
# 10000E8C_anon.png: CAP (99.82%), bbox=(np.int64(119), np.int64(201), np.int64(450), np.int64(425))
# 10000E8D_anon.png: CAP (99.92%), bbox=(np.int64(117), np.int64(198), np.int64(469), np.int64(418))
# 10000E8E_anon.png: CAP (99.97%), bbox=(np.int64(104), np.int64(183), np.int64(511), np.int64(421))
# 10000E8F_anon.png: CAP (99.96%), bbox=(np.int64(89), np.int64(194), np.int64(511), np.int64(428))
# 10000E90_anon.png: CAP (99.97%), bbox=(np.int64(99), np.int64(191), np.int64(470), np.int64(422))
# 10000E91_anon.png: CAP (99.98%), bbox=(np.int64(95), np.int64(193), np.int64(463), np.int64(418))
# 10000E92_anon.png: CAP (99.98%), bbox=(np.int64(89), np.int64(192), np.int64(451), np.int64(421))
# 10000E93_anon.png: CAP (99.97%), bbox=(np.int64(81), np.int64(201), np.int64(451), np.int64(427))
# 10000E94_anon.png: CAP (99.98%), bbox=(np.int64(85), np.int64(197), np.int64(452), np.int64(427))
# 10000E95_anon.png: CAP (99.99%), bbox=(np.int64(75), np.int64(198), np.int64(455), np.int64(424))
# 10000E96_anon.png: CAP (99.99%), bbox=(np.int64(64), np.int64(200), np.int64(453), np.int64(427))
# 10000E97_anon.png: CAP (99.95%), bbox=(np.int64(69), np.int64(89), np.int64(468), np.int64(437))
# 10000E98_anon.png: CAP (99.96%), bbox=(np.int64(71), np.int64(99), np.int64(461), np.int64(438))
# 10000E99_anon.png: CAP (99.96%), bbox=(np.int64(70), np.int64(102), np.int64(456), np.int64(437))
# 10000E9A_anon.png: CAP (99.88%), bbox=(np.int64(73), np.int64(73), np.int64(451), np.int64(440))
# 10000E9B_anon.png: CAP (99.92%), bbox=(np.int64(78), np.int64(61), np.int64(460), np.int64(440))
# 10000E9C_anon.png: CAP (99.98%), bbox=(np.int64(82), np.int64(82), np.int64(471), np.int64(438))
# 10000E9D_anon.png: CAP (99.98%), bbox=(np.int64(82), np.int64(107), np.int64(460), np.int64(436))
# 10000E9E_anon.png: CAP (99.98%), bbox=(np.int64(81), np.int64(205), np.int64(449), np.int64(435))
# 10000E9F_anon.png: CAP (99.97%), bbox=(np.int64(87), np.int64(209), np.int64(446), np.int64(434))
# 10000EA0_anon.png: CAP (99.98%), bbox=(np.int64(88), np.int64(209), np.int64(441), np.int64(433))
# 10000EA1_anon.png: CAP (99.98%), bbox=(np.int64(95), np.int64(212), np.int64(444), np.int64(432))
# 10000EA2_anon.png: CAP (99.99%), bbox=(np.int64(96), np.int64(213), np.int64(448), np.int64(431))
# 10000EA3_anon.png: CAP (100.00%), bbox=(np.int64(92), np.int64(207), np.int64(451), np.int64(430))
# 10000EA4_anon.png: CAP (100.00%), bbox=(np.int64(95), np.int64(203), np.int64(443), np.int64(431))
# 10000EA5_anon.png: CAP (99.99%), bbox=(np.int64(88), np.int64(206), np.int64(436), np.int64(433))
# 10000EA6_anon.png: CAP (100.00%), bbox=(np.int64(94), np.int64(208), np.int64(435), np.int64(432))
# 10000EA7_anon.png: CAP (100.00%), bbox=(np.int64(92), np.int64(215), np.int64(432), np.int64(432))
# 10000EA8_anon.png: CAP (100.00%), bbox=(np.int64(87), np.int64(211), np.int64(420), np.int64(432))
# 10000EA9_anon.png: CAP (100.00%), bbox=(np.int64(77), np.int64(197), np.int64(413), np.int64(433))
# 10000EAA_anon.png: CAP (100.00%), bbox=(np.int64(89), np.int64(208), np.int64(409), np.int64(436))
# 10000EAB_anon.png: CAP (100.00%), bbox=(np.int64(92), np.int64(203), np.int64(408), np.int64(436))
# 10000EAC_anon.png: CAP (100.00%), bbox=(np.int64(87), np.int64(202), np.int64(415), np.int64(437))
# 10000EAD_anon.png: CAP (100.00%), bbox=(np.int64(85), np.int64(205), np.int64(418), np.int64(436))
# 10000EAE_anon.png: CAP (100.00%), bbox=(np.int64(99), np.int64(204), np.int64(422), np.int64(437))
# 10000EAF_anon.png: CAP (100.00%), bbox=(np.int64(92), np.int64(196), np.int64(416), np.int64(436))
# 10000EB0_anon.png: CAP (100.00%), bbox=(np.int64(74), np.int64(189), np.int64(400), np.int64(437))
# 10000EB1_anon.png: CAP (100.00%), bbox=(np.int64(78), np.int64(194), np.int64(397), np.int64(438))
# 10000EB2_anon.png: CAP (100.00%), bbox=(np.int64(63), np.int64(186), np.int64(397), np.int64(441))
# 10000EB3_anon.png: CAP (100.00%), bbox=(np.int64(80), np.int64(101), np.int64(411), np.int64(443))
# 10000EB4_anon.png: CAP (99.99%), bbox=(np.int64(99), np.int64(82), np.int64(401), np.int64(445))
# 10000EB5_anon.png: CAP (99.99%), bbox=(np.int64(93), np.int64(84), np.int64(401), np.int64(446))
# 10000EB6_anon.png: CAP (100.00%), bbox=(np.int64(84), np.int64(87), np.int64(414), np.int64(446))
# 10000EB7_anon.png: CAP (99.99%), bbox=(np.int64(111), np.int64(89), np.int64(415), np.int64(445))
# 10000EB8_anon.png: CAP (99.99%), bbox=(np.int64(104), np.int64(76), np.int64(420), np.int64(448))
# 10000EB9_anon.png: CAP (99.99%), bbox=(np.int64(103), np.int64(75), np.int64(430), np.int64(447))
# 10000EBA_anon.png: CAP (99.99%), bbox=(np.int64(106), np.int64(72), np.int64(436), np.int64(446))
# 10000EBB_anon.png: CAP (99.99%), bbox=(np.int64(101), np.int64(73), np.int64(427), np.int64(447))
# 10000EBC_anon.png: CAP (99.98%), bbox=(np.int64(97), np.int64(65), np.int64(424), np.int64(448))
# 10000EBD_anon.png: CAP (99.99%), bbox=(np.int64(117), np.int64(80), np.int64(437), np.int64(444))
# 10000EBE_anon.png: CAP (99.98%), bbox=(np.int64(123), np.int64(72), np.int64(450), np.int64(445))
# 10000EBF_anon.png: CAP (99.97%), bbox=(np.int64(99), np.int64(43), np.int64(437), np.int64(450))
# 10000EC0_anon.png: CAP (99.98%), bbox=(np.int64(107), np.int64(83), np.int64(437), np.int64(448))
# 10000EC1_anon.png: CAP (99.98%), bbox=(np.int64(112), np.int64(87), np.int64(423), np.int64(448))
# 10000EC2_anon.png: CAP (99.98%), bbox=(np.int64(116), np.int64(217), np.int64(417), np.int64(447))
# 10000EC3_anon.png: CAP (99.98%), bbox=(np.int64(119), np.int64(215), np.int64(417), np.int64(446))
# 10000EC4_anon.png: CAP (99.99%), bbox=(np.int64(115), np.int64(201), np.int64(415), np.int64(447))
# 10000EC5_anon.png: CAP (99.99%), bbox=(np.int64(103), np.int64(212), np.int64(414), np.int64(446))
# 10000EC6_anon.png: CAP (99.99%), bbox=(np.int64(101), np.int64(215), np.int64(409), np.int64(445))
# 10000EC7_anon.png: CAP (99.99%), bbox=(np.int64(100), np.int64(211), np.int64(426), np.int64(448))
# 10000EC8_anon.png: CAP (99.99%), bbox=(np.int64(105), np.int64(209), np.int64(412), np.int64(446))
# 10000EC9_anon.png: CAP (99.97%), bbox=(np.int64(114), np.int64(226), np.int64(396), np.int64(448))
# 10000ECA_anon.png: CAP (99.98%), bbox=(np.int64(120), np.int64(102), np.int64(418), np.int64(450))
# 10000ECB_anon.png: CAP (99.98%), bbox=(np.int64(128), np.int64(71), np.int64(413), np.int64(450))
# 10000ECC_anon.png: CAP (99.97%), bbox=(np.int64(132), np.int64(58), np.int64(415), np.int64(451))
# 10000ECD_anon.png: CAP (99.96%), bbox=(np.int64(125), np.int64(52), np.int64(411), np.int64(452))
# 10000ECE_anon.png: CAP (99.97%), bbox=(np.int64(130), np.int64(57), np.int64(408), np.int64(451))
# 10000ECF_anon.png: CAP (99.96%), bbox=(np.int64(119), np.int64(46), np.int64(411), np.int64(451))
# 10000ED0_anon.png: CAP (99.97%), bbox=(np.int64(123), np.int64(43), np.int64(418), np.int64(452))
# 10000ED1_anon.png: CAP (99.98%), bbox=(np.int64(132), np.int64(56), np.int64(419), np.int64(448))
# 10000ED2_anon.png: CAP (99.98%), bbox=(np.int64(130), np.int64(57), np.int64(416), np.int64(450))
# 10000ED3_anon.png: CAP (99.94%), bbox=(np.int64(126), np.int64(48), np.int64(422), np.int64(452))
# 10000ED4_anon.png: CAP (99.94%), bbox=(np.int64(114), np.int64(0), np.int64(415), np.int64(455))
# 10000ED5_anon.png: CAP (99.95%), bbox=(np.int64(103), np.int64(0), np.int64(411), np.int64(456))
# 10000ED6_anon.png: CAP (99.91%), bbox=(np.int64(90), np.int64(0), np.int64(404), np.int64(456))
# 10000ED7_anon.png: CAP (99.88%), bbox=(np.int64(100), np.int64(0), np.int64(402), np.int64(454))
# 10000ED8_anon.png: CAP (99.79%), bbox=(np.int64(78), np.int64(0), np.int64(423), np.int64(461))
# 10000ED9_anon.png: CAP (99.61%), bbox=(np.int64(65), np.int64(0), np.int64(440), np.int64(467))
# 10000EDA_anon.png: CAP (99.54%), bbox=(np.int64(59), np.int64(0), np.int64(437), np.int64(468))
# 10000EDB_anon.png: CAP (99.26%), bbox=(np.int64(50), np.int64(0), np.int64(450), np.int64(472))
# 10000EDC_anon.png: CAP (98.97%), bbox=(np.int64(50), np.int64(0), np.int64(457), np.int64(473))
# 10000EDD_anon.png: CAP (99.22%), bbox=(np.int64(61), np.int64(0), np.int64(454), np.int64(472))
# 10000EDE_anon.png: CAP (98.86%), bbox=(np.int64(60), np.int64(0), np.int64(447), np.int64(472))
# 10000EDF_anon.png: CAP (97.63%), bbox=(np.int64(61), np.int64(0), np.int64(451), np.int64(473))
# 10000EE0_anon.png: CAP (97.34%), bbox=(np.int64(80), np.int64(0), np.int64(444), np.int64(471))
# 10000EE1_anon.png: CAP (97.88%), bbox=(np.int64(101), np.int64(0), np.int64(427), np.int64(467))
# 10000EE2_anon.png: CAP (98.04%), bbox=(np.int64(98), np.int64(0), np.int64(430), np.int64(468))
# 10000EE3_anon.png: CAP (97.99%), bbox=(np.int64(95), np.int64(0), np.int64(437), np.int64(469))
# 10000EE4_anon.png: CAP (96.32%), bbox=(np.int64(83), np.int64(0), np.int64(440), np.int64(472))
# 10000EE5_anon.png: CAP (96.96%), bbox=(np.int64(92), np.int64(0), np.int64(439), np.int64(468))
# 10000EE6_anon.png: CAP (97.62%), bbox=(np.int64(105), np.int64(0), np.int64(427), np.int64(463))
# 10000EE7_anon.png: CAP (96.84%), bbox=(np.int64(107), np.int64(0), np.int64(420), np.int64(465))
# 10000EE8_anon.png: CAP (96.78%), bbox=(np.int64(106), np.int64(0), np.int64(423), np.int64(468))
# 10000EE9_anon.png: CAP (94.31%), bbox=(np.int64(92), np.int64(0), np.int64(440), np.int64(511))
# 10000EEA_anon.png: CAP (91.12%), bbox=(np.int64(75), np.int64(0), np.int64(457), np.int64(511))
# 10000EEB_anon.png: CAP (95.78%), bbox=(np.int64(81), np.int64(0), np.int64(453), np.int64(511))
# 10000EEC_anon.png: CAP (94.09%), bbox=(np.int64(80), np.int64(0), np.int64(457), np.int64(511))
# 10000EED_anon.png: CAP (95.86%), bbox=(np.int64(77), np.int64(0), np.int64(458), np.int64(511))
# 10000EEE_anon.png: CAP (96.19%), bbox=(np.int64(76), np.int64(0), np.int64(458), np.int64(511))
# 10000EEF_anon.png: CAP (96.98%), bbox=(np.int64(59), np.int64(0), np.int64(468), np.int64(511))
# 10000EF0_anon.png: CAP (97.00%), bbox=(np.int64(74), np.int64(0), np.int64(466), np.int64(511))
# 10000EF1_anon.png: CAP (96.00%), bbox=(np.int64(71), np.int64(0), np.int64(468), np.int64(511))
# 10000EF2_anon.png: CAP (96.86%), bbox=(np.int64(61), np.int64(0), np.int64(472), np.int64(511))
# 10000EF3_anon.png: CAP (95.02%), bbox=(np.int64(62), np.int64(0), np.int64(472), np.int64(511))
# 10000EF4_anon.png: CAP (92.41%), bbox=(np.int64(60), np.int64(0), np.int64(474), np.int64(511))
# 10000EF5_anon.png: CAP (90.02%), bbox=(np.int64(48), np.int64(0), np.int64(511), np.int64(511))
# 10000EF6_anon.png: CAP (78.11%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000EF7_anon.png: CAP (70.27%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000EF8_anon.png: CAP (69.41%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000EF9_anon.png: CAP (71.11%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000EFA_anon.png: CAP (75.25%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000EFB_anon.png: CAP (75.71%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000EFC_anon.png: CAP (82.73%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000EFD_anon.png: CAP (81.36%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000EFE_anon.png: CAP (85.40%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000EFF_anon.png: CAP (82.07%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F00_anon.png: CAP (87.30%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F01_anon.png: CAP (91.32%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F02_anon.png: CAP (96.02%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F03_anon.png: CAP (97.88%), bbox=(np.int64(49), np.int64(0), np.int64(511), np.int64(511))
# 10000F04_anon.png: CAP (95.70%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F05_anon.png: CAP (93.55%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F06_anon.png: CAP (95.18%), bbox=(np.int64(40), np.int64(0), np.int64(511), np.int64(511))
# 10000F07_anon.png: CAP (96.03%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F08_anon.png: CAP (96.09%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F09_anon.png: CAP (95.73%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F0A_anon.png: CAP (93.76%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F0B_anon.png: CAP (91.18%), bbox=(np.int64(46), np.int64(0), np.int64(511), np.int64(511))
# 10000F0C_anon.png: CAP (88.93%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F0D_anon.png: CAP (91.61%), bbox=(np.int64(53), np.int64(0), np.int64(511), np.int64(511))
# 10000F0E_anon.png: CAP (89.70%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F0F_anon.png: CAP (90.15%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F10_anon.png: CAP (83.47%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F11_anon.png: CAP (88.65%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F12_anon.png: CAP (89.51%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F13_anon.png: CAP (81.99%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F14_anon.png: CAP (85.81%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F15_anon.png: CAP (85.47%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F16_anon.png: CAP (88.52%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F17_anon.png: CAP (81.91%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F18_anon.png: CAP (91.72%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F19_anon.png: CAP (86.64%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F1A_anon.png: CAP (71.50%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F1B_anon.png: CAP (68.80%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F1C_anon.png: CAP (66.07%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F1D_anon.png: CAP (54.92%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F1E_anon.png: CAP (64.12%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F1F_anon.png: CAP (72.16%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F20_anon.png: CAP (79.93%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F21_anon.png: CAP (74.03%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F22_anon.png: CAP (77.60%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F23_anon.png: CAP (80.36%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F24_anon.png: CAP (79.99%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F25_anon.png: CAP (85.68%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F26_anon.png: CAP (82.39%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F27_anon.png: CAP (74.70%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F28_anon.png: CAP (85.26%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F29_anon.png: CAP (84.83%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F2A_anon.png: CAP (72.64%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F2B_anon.png: CAP (70.94%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F2C_anon.png: CAP (72.35%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F2D_anon.png: CAP (67.45%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F2E_anon.png: CAP (74.19%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F2F_anon.png: CAP (79.28%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F30_anon.png: CAP (81.83%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F31_anon.png: CAP (86.34%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F32_anon.png: CAP (77.88%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F33_anon.png: CAP (65.41%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F34_anon.png: CAP (76.43%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F35_anon.png: CAP (78.33%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F36_anon.png: CAP (84.11%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F37_anon.png: CAP (87.22%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F38_anon.png: CAP (88.03%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F39_anon.png: CAP (82.68%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F3A_anon.png: CAP (61.35%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F3B_anon.png: CAP (54.21%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F3C_anon.png: CAP (56.69%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F3D_anon.png: CAP (56.01%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F3E_anon.png: CAP (61.13%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F3F_anon.png: CAP (69.55%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F40_anon.png: COVID-19 (51.86%), bbox=(np.int64(66), np.int64(205), np.int64(443), np.int64(416))
# 10000F41_anon.png: COVID-19 (58.60%), bbox=(np.int64(53), np.int64(205), np.int64(439), np.int64(418))
# 10000F42_anon.png: COVID-19 (57.42%), bbox=(np.int64(70), np.int64(204), np.int64(435), np.int64(415))
# 10000F43_anon.png: COVID-19 (62.82%), bbox=(np.int64(71), np.int64(205), np.int64(438), np.int64(411))
# 10000F44_anon.png: COVID-19 (56.09%), bbox=(np.int64(51), np.int64(207), np.int64(444), np.int64(410))
# 10000F45_anon.png: CAP (62.61%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F46_anon.png: CAP (53.25%), bbox=(np.int64(0), np.int64(0), np.int64(511), np.int64(511))
# 10000F47_anon.png: COVID-19 (59.96%), bbox=(np.int64(68), np.int64(202), np.int64(429), np.int64(409))
# 10000F48_anon.png: COVID-19 (71.10%), bbox=(np.int64(70), np.int64(199), np.int64(427), np.int64(402))
# 10000F49_anon.png: COVID-19 (56.16%), bbox=(np.int64(57), np.int64(202), np.int64(428), np.int64(404))
# 10000F4A_anon.png: COVID-19 (52.22%), bbox=(np.int64(61), np.int64(204), np.int64(430), np.int64(410))
# 10000F4B_anon.png: COVID-19 (52.08%), bbox=(np.int64(63), np.int64(205), np.int64(437), np.int64(410))
# 10000F4C_anon.png: COVID-19 (49.28%), bbox=(np.int64(66), np.int64(207), np.int64(437), np.int64(413))
# 10000F4D_anon.png: COVID-19 (64.55%), bbox=(np.int64(51), np.int64(205), np.int64(445), np.int64(418))
# 10000F4E_anon.png: COVID-19 (61.37%), bbox=(np.int64(61), np.int64(205), np.int64(442), np.int64(409))
# 10000F4F_anon.png: COVID-19 (75.90%), bbox=(np.int64(52), np.int64(207), np.int64(448), np.int64(417))
# 10000F50_anon.png: COVID-19 (84.38%), bbox=(np.int64(68), np.int64(205), np.int64(456), np.int64(408))
# 10000F51_anon.png: COVID-19 (85.64%), bbox=(np.int64(66), np.int64(203), np.int64(444), np.int64(411))
# 10000F52_anon.png: COVID-19 (82.38%), bbox=(np.int64(58), np.int64(204), np.int64(443), np.int64(412))
# 10000F53_anon.png: COVID-19 (85.21%), bbox=(np.int64(60), np.int64(204), np.int64(442), np.int64(412))
# 10000F54_anon.png: COVID-19 (78.07%), bbox=(np.int64(51), np.int64(206), np.int64(454), np.int64(415))
# 10000F55_anon.png: COVID-19 (80.97%), bbox=(np.int64(54), np.int64(209), np.int64(451), np.int64(423))
# 10000F56_anon.png: COVID-19 (69.18%), bbox=(np.int64(0), np.int64(213), np.int64(511), np.int64(433))
# 10000F57_anon.png: COVID-19 (52.23%), bbox=(np.int64(0), np.int64(215), np.int64(463), np.int64(428))
# 10000F58_anon.png: COVID-19 (69.26%), bbox=(np.int64(0), np.int64(208), np.int64(446), np.int64(423))
# 10000F59_anon.png: COVID-19 (74.75%), bbox=(np.int64(0), np.int64(212), np.int64(437), np.int64(418))
# 10000F5A_anon.png: COVID-19 (74.59%), bbox=(np.int64(0), np.int64(217), np.int64(452), np.int64(415))
# 10000F5B_anon.png: COVID-19 (65.25%), bbox=(np.int64(0), np.int64(219), np.int64(471), np.int64(422))
# 10000F5C_anon.png: COVID-19 (62.01%), bbox=(np.int64(0), np.int64(213), np.int64(459), np.int64(420))
# 10000F5D_anon.png: COVID-19 (74.84%), bbox=(np.int64(45), np.int64(208), np.int64(461), np.int64(408))
# 10000F5E_anon.png: COVID-19 (76.46%), bbox=(np.int64(48), np.int64(207), np.int64(456), np.int64(413))
# 10000F5F_anon.png: COVID-19 (74.91%), bbox=(np.int64(53), np.int64(206), np.int64(451), np.int64(413))
# 10000F60_anon.png: COVID-19 (77.94%), bbox=(np.int64(0), np.int64(208), np.int64(456), np.int64(420))
# 10000F61_anon.png: COVID-19 (87.88%), bbox=(np.int64(51), np.int64(202), np.int64(454), np.int64(412))
# 10000F62_anon.png: COVID-19 (90.40%), bbox=(np.int64(47), np.int64(201), np.int64(451), np.int64(412))
# 10000F63_anon.png: COVID-19 (90.23%), bbox=(np.int64(47), np.int64(202), np.int64(455), np.int64(412))
# 10000F64_anon.png: COVID-19 (89.40%), bbox=(np.int64(0), np.int64(207), np.int64(467), np.int64(420))
# 10000F65_anon.png: COVID-19 (81.73%), bbox=(np.int64(0), np.int64(209), np.int64(461), np.int64(417))
# 10000F66_anon.png: COVID-19 (78.57%), bbox=(np.int64(44), np.int64(202), np.int64(454), np.int64(406))
# 10000F67_anon.png: COVID-19 (83.94%), bbox=(np.int64(49), np.int64(204), np.int64(454), np.int64(409))
# 10000F68_anon.png: COVID-19 (83.07%), bbox=(np.int64(43), np.int64(206), np.int64(457), np.int64(411))
# 10000F69_anon.png: COVID-19 (79.92%), bbox=(np.int64(52), np.int64(205), np.int64(457), np.int64(407))
# 10000F6A_anon.png: COVID-19 (71.20%), bbox=(np.int64(59), np.int64(204), np.int64(462), np.int64(405))
# 10000F6B_anon.png: COVID-19 (70.55%), bbox=(np.int64(40), np.int64(208), np.int64(511), np.int64(415))
# 10000F6C_anon.png: COVID-19 (64.09%), bbox=(np.int64(38), np.int64(210), np.int64(473), np.int64(416))
# 10000F6D_anon.png: COVID-19 (76.63%), bbox=(np.int64(39), np.int64(206), np.int64(461), np.int64(416))
# 10000F6E_anon.png: COVID-19 (75.49%), bbox=(np.int64(0), np.int64(207), np.int64(460), np.int64(419))
# 10000F6F_anon.png: COVID-19 (79.76%), bbox=(np.int64(0), np.int64(203), np.int64(449), np.int64(415))
# 10000F70_anon.png: COVID-19 (81.70%), bbox=(np.int64(0), np.int64(205), np.int64(437), np.int64(416))
# 10000F71_anon.png: COVID-19 (79.97%), bbox=(np.int64(0), np.int64(197), np.int64(445), np.int64(412))
# 10000F72_anon.png: COVID-19 (79.04%), bbox=(np.int64(0), np.int64(201), np.int64(451), np.int64(414))
# 10000F73_anon.png: COVID-19 (89.33%), bbox=(np.int64(0), np.int64(194), np.int64(443), np.int64(413))
# 10000F74_anon.png: COVID-19 (80.38%), bbox=(np.int64(0), np.int64(202), np.int64(442), np.int64(422))
# 10000F75_anon.png: COVID-19 (73.36%), bbox=(np.int64(0), np.int64(206), np.int64(444), np.int64(421))
# 10000F76_anon.png: COVID-19 (83.39%), bbox=(np.int64(0), np.int64(205), np.int64(446), np.int64(420))
# 10000F77_anon.png: COVID-19 (81.80%), bbox=(np.int64(0), np.int64(210), np.int64(442), np.int64(416))
# 10000F78_anon.png: COVID-19 (78.35%), bbox=(np.int64(0), np.int64(208), np.int64(443), np.int64(415))
# 10000F79_anon.png: COVID-19 (77.47%), bbox=(np.int64(0), np.int64(206), np.int64(450), np.int64(413))
# 10000F7A_anon.png: COVID-19 (74.87%), bbox=(np.int64(0), np.int64(206), np.int64(457), np.int64(415))
# 10000F7B_anon.png: COVID-19 (80.73%), bbox=(np.int64(0), np.int64(203), np.int64(463), np.int64(414))
# 10000F7C_anon.png: COVID-19 (86.81%), bbox=(np.int64(0), np.int64(199), np.int64(464), np.int64(411))
# 10000F7D_anon.png: COVID-19 (87.67%), bbox=(np.int64(0), np.int64(200), np.int64(462), np.int64(410))
# 10000F7E_anon.png: COVID-19 (93.88%), bbox=(np.int64(0), np.int64(199), np.int64(465), np.int64(409))
# 10000F7F_anon.png: COVID-19 (94.27%), bbox=(np.int64(0), np.int64(200), np.int64(461), np.int64(406))
# 10000F80_anon.png: COVID-19 (92.30%), bbox=(np.int64(0), np.int64(204), np.int64(464), np.int64(412))
# 10000F81_anon.png: COVID-19 (92.57%), bbox=(np.int64(0), np.int64(207), np.int64(468), np.int64(415))
# 10000F82_anon.png: COVID-19 (92.73%), bbox=(np.int64(0), np.int64(203), np.int64(467), np.int64(415))
# 10000F83_anon.png: COVID-19 (94.03%), bbox=(np.int64(0), np.int64(200), np.int64(462), np.int64(414))
# 10000F84_anon.png: COVID-19 (95.72%), bbox=(np.int64(0), np.int64(201), np.int64(457), np.int64(408))
# 10000F85_anon.png: COVID-19 (92.97%), bbox=(np.int64(0), np.int64(203), np.int64(461), np.int64(416))
# 10000F86_anon.png: COVID-19 (93.27%), bbox=(np.int64(0), np.int64(201), np.int64(451), np.int64(410))
# 10000F87_anon.png: COVID-19 (94.51%), bbox=(np.int64(0), np.int64(198), np.int64(455), np.int64(408))
# 10000F88_anon.png: COVID-19 (93.21%), bbox=(np.int64(0), np.int64(206), np.int64(455), np.int64(416))
# 10000F89_anon.png: COVID-19 (94.30%), bbox=(np.int64(0), np.int64(201), np.int64(445), np.int64(415))
# 10000F8A_anon.png: COVID-19 (92.25%), bbox=(np.int64(0), np.int64(201), np.int64(448), np.int64(418))
# 10000F8B_anon.png: COVID-19 (92.37%), bbox=(np.int64(0), np.int64(202), np.int64(464), np.int64(419))
# 10000F8C_anon.png: COVID-19 (90.21%), bbox=(np.int64(0), np.int64(210), np.int64(454), np.int64(418))
# 10000F8D_anon.png: COVID-19 (88.64%), bbox=(np.int64(0), np.int64(204), np.int64(462), np.int64(418))
# 10000F8E_anon.png: COVID-19 (88.60%), bbox=(np.int64(0), np.int64(202), np.int64(456), np.int64(420))
# 10000F8F_anon.png: COVID-19 (90.24%), bbox=(np.int64(0), np.int64(202), np.int64(449), np.int64(420))
# 10000F90_anon.png: COVID-19 (93.67%), bbox=(np.int64(37), np.int64(199), np.int64(434), np.int64(415))
# 10000F91_anon.png: COVID-19 (91.97%), bbox=(np.int64(0), np.int64(205), np.int64(429), np.int64(414))
# 10000F92_anon.png: COVID-19 (92.39%), bbox=(np.int64(0), np.int64(205), np.int64(431), np.int64(415))
# 10000F93_anon.png: COVID-19 (91.76%), bbox=(np.int64(0), np.int64(207), np.int64(432), np.int64(416))
# 10000F94_anon.png: COVID-19 (88.79%), bbox=(np.int64(0), np.int64(212), np.int64(443), np.int64(418))
# 10000F95_anon.png: COVID-19 (88.79%), bbox=(np.int64(0), np.int64(212), np.int64(434), np.int64(417))
# 10000F96_anon.png: COVID-19 (87.76%), bbox=(np.int64(0), np.int64(217), np.int64(427), np.int64(416))
# 10000F97_anon.png: COVID-19 (87.13%), bbox=(np.int64(0), np.int64(217), np.int64(425), np.int64(416))
# 10000F98_anon.png: COVID-19 (89.36%), bbox=(np.int64(0), np.int64(214), np.int64(429), np.int64(416))
# 10000F99_anon.png: COVID-19 (79.59%), bbox=(np.int64(0), np.int64(216), np.int64(433), np.int64(412))
# 10000F9A_anon.png: COVID-19 (84.91%), bbox=(np.int64(0), np.int64(217), np.int64(433), np.int64(413))
# 10000F9B_anon.png: COVID-19 (82.07%), bbox=(np.int64(0), np.int64(215), np.int64(426), np.int64(413))
# 10000F9C_anon.png: COVID-19 (89.06%), bbox=(np.int64(0), np.int64(215), np.int64(433), np.int64(415))
# 10000F9D_anon.png: COVID-19 (87.75%), bbox=(np.int64(0), np.int64(216), np.int64(435), np.int64(417))
# 10000F9E_anon.png: COVID-19 (85.54%), bbox=(np.int64(0), np.int64(215), np.int64(442), np.int64(415))
# 10000F9F_anon.png: COVID-19 (87.49%), bbox=(np.int64(0), np.int64(214), np.int64(437), np.int64(413))
# 10000FA0_anon.png: COVID-19 (82.58%), bbox=(np.int64(0), np.int64(214), np.int64(425), np.int64(414))
# 10000FA1_anon.png: COVID-19 (77.74%), bbox=(np.int64(0), np.int64(213), np.int64(413), np.int64(412))
# 10000FA2_anon.png: COVID-19 (81.05%), bbox=(np.int64(0), np.int64(215), np.int64(443), np.int64(415))
# 10000FA3_anon.png: COVID-19 (69.07%), bbox=(np.int64(0), np.int64(215), np.int64(461), np.int64(412))
# 10000FA4_anon.png: COVID-19 (67.25%), bbox=(np.int64(0), np.int64(215), np.int64(465), np.int64(408))
# 10000FA5_anon.png: COVID-19 (61.05%), bbox=(np.int64(0), np.int64(215), np.int64(468), np.int64(405))
# 10000FA6_anon.png: COVID-19 (57.32%), bbox=(np.int64(0), np.int64(216), np.int64(458), np.int64(409))
# 10000FA7_anon.png: COVID-19 (50.89%), bbox=(np.int64(0), np.int64(216), np.int64(468), np.int64(407))
# 10000FA8_anon.png: COVID-19 (52.14%), bbox=(np.int64(0), np.int64(216), np.int64(463), np.int64(407))
# 10000FA9_anon.png: COVID-19 (68.02%), bbox=(np.int64(0), np.int64(215), np.int64(461), np.int64(407))
# 10000FAA_anon.png: COVID-19 (65.62%), bbox=(np.int64(0), np.int64(215), np.int64(457), np.int64(408))
# 10000FAB_anon.png: COVID-19 (57.33%), bbox=(np.int64(0), np.int64(214), np.int64(469), np.int64(400))
# 10000FAC_anon.png: COVID-19 (54.83%), bbox=(np.int64(0), np.int64(213), np.int64(511), np.int64(401))
# 10000FAD_anon.png: COVID-19 (59.18%), bbox=(np.int64(0), np.int64(213), np.int64(511), np.int64(407))
# 10000FAE_anon.png: COVID-19 (82.16%), bbox=(np.int64(44), np.int64(208), np.int64(470), np.int64(401))
# 10000FAF_anon.png: COVID-19 (89.90%), bbox=(np.int64(50), np.int64(205), np.int64(460), np.int64(396))
# 10000FB0_anon.png: COVID-19 (94.23%), bbox=(np.int64(59), np.int64(202), np.int64(453), np.int64(388))
# 10000FB1_anon.png: COVID-19 (95.76%), bbox=(np.int64(63), np.int64(199), np.int64(452), np.int64(378))
# 10000FB2_anon.png: COVID-19 (96.87%), bbox=(np.int64(70), np.int64(193), np.int64(454), np.int64(375))
# 10000FB3_anon.png: COVID-19 (95.99%), bbox=(np.int64(72), np.int64(191), np.int64(457), np.int64(368))
# 10000FB4_anon.png: COVID-19 (95.47%), bbox=(np.int64(75), np.int64(190), np.int64(461), np.int64(364))
# 10000FB5_anon.png: COVID-19 (92.74%), bbox=(np.int64(83), np.int64(188), np.int64(461), np.int64(363))
# 10000FB6_anon.png: COVID-19 (95.54%), bbox=(np.int64(71), np.int64(189), np.int64(461), np.int64(374))
# 10000FB7_anon.png: COVID-19 (95.72%), bbox=(np.int64(67), np.int64(189), np.int64(461), np.int64(372))
# 10000FB8_anon.png: COVID-19 (95.85%), bbox=(np.int64(69), np.int64(190), np.int64(463), np.int64(376))
# 10000FB9_anon.png: COVID-19 (97.87%), bbox=(np.int64(62), np.int64(193), np.int64(462), np.int64(394))
# 10000FBA_anon.png: COVID-19 (98.55%), bbox=(np.int64(64), np.int64(193), np.int64(458), np.int64(388))
# 10000FBB_anon.png: COVID-19 (98.57%), bbox=(np.int64(66), np.int64(194), np.int64(460), np.int64(390))
# 10000FBC_anon.png: COVID-19 (98.10%), bbox=(np.int64(62), np.int64(198), np.int64(461), np.int64(393))
# 10000FBD_anon.png: COVID-19 (98.96%), bbox=(np.int64(63), np.int64(198), np.int64(460), np.int64(393))
# 10000FBE_anon.png: COVID-19 (99.36%), bbox=(np.int64(66), np.int64(194), np.int64(450), np.int64(386))
# 10000FBF_anon.png: COVID-19 (99.32%), bbox=(np.int64(66), np.int64(191), np.int64(451), np.int64(388))
# 10000FC0_anon.png: COVID-19 (99.56%), bbox=(np.int64(69), np.int64(187), np.int64(448), np.int64(383))
# 10000FC1_anon.png: COVID-19 (99.50%), bbox=(np.int64(68), np.int64(186), np.int64(450), np.int64(383))
# 10000FC2_anon.png: COVID-19 (99.56%), bbox=(np.int64(71), np.int64(183), np.int64(452), np.int64(381))
# 10000FC3_anon.png: COVID-19 (99.57%), bbox=(np.int64(70), np.int64(186), np.int64(453), np.int64(386))
# 10000FC4_anon.png: COVID-19 (99.08%), bbox=(np.int64(69), np.int64(190), np.int64(458), np.int64(387))
# 10000FC5_anon.png: COVID-19 (99.26%), bbox=(np.int64(75), np.int64(185), np.int64(457), np.int64(378))
# 10000FC6_anon.png: COVID-19 (98.11%), bbox=(np.int64(67), np.int64(190), np.int64(461), np.int64(386))
# 10000FC7_anon.png: COVID-19 (97.17%), bbox=(np.int64(63), np.int64(190), np.int64(460), np.int64(389))
# 10000FC8_anon.png: COVID-19 (96.33%), bbox=(np.int64(61), np.int64(192), np.int64(462), np.int64(392))
# 10000FC9_anon.png: COVID-19 (97.08%), bbox=(np.int64(61), np.int64(187), np.int64(465), np.int64(394))
# 10000FCA_anon.png: COVID-19 (96.12%), bbox=(np.int64(55), np.int64(187), np.int64(472), np.int64(401))
# 10000FCB_anon.png: COVID-19 (94.43%), bbox=(np.int64(54), np.int64(193), np.int64(472), np.int64(403))
# 10000FCC_anon.png: COVID-19 (94.91%), bbox=(np.int64(55), np.int64(193), np.int64(472), np.int64(403))
# 10000FCD_anon.png: COVID-19 (91.61%), bbox=(np.int64(55), np.int64(198), np.int64(471), np.int64(403))
# 10000FCE_anon.png: COVID-19 (89.34%), bbox=(np.int64(54), np.int64(198), np.int64(511), np.int64(407))
# 10000FCF_anon.png: COVID-19 (88.52%), bbox=(np.int64(56), np.int64(201), np.int64(469), np.int64(406))
# 10000FD0_anon.png: COVID-19 (88.13%), bbox=(np.int64(56), np.int64(199), np.int64(464), np.int64(403))
# 10000FD1_anon.png: COVID-19 (85.67%), bbox=(np.int64(57), np.int64(197), np.int64(511), np.int64(410))
# 10000FD2_anon.png: COVID-19 (81.99%), bbox=(np.int64(56), np.int64(204), np.int64(511), np.int64(410))
# 10000FD3_anon.png: COVID-19 (79.46%), bbox=(np.int64(55), np.int64(202), np.int64(511), np.int64(411))
# 10000FD4_anon.png: COVID-19 (81.52%), bbox=(np.int64(58), np.int64(192), np.int64(511), np.int64(411))
# 10000FD5_anon.png: COVID-19 (88.92%), bbox=(np.int64(61), np.int64(195), np.int64(511), np.int64(405))
# 10000FD6_anon.png: COVID-19 (68.83%), bbox=(np.int64(58), np.int64(187), np.int64(511), np.int64(410))
# 10000FD7_anon.png: COVID-19 (56.23%), bbox=(np.int64(59), np.int64(190), np.int64(511), np.int64(413))
# 10000FD8_anon.png: COVID-19 (57.06%), bbox=(np.int64(55), np.int64(190), np.int64(511), np.int64(411))
# 10000FD9_anon.png: CAP (55.79%), bbox=(np.int64(52), np.int64(0), np.int64(511), np.int64(511))
# 10000FDA_anon.png: COVID-19 (59.36%), bbox=(np.int64(60), np.int64(197), np.int64(511), np.int64(410))
# 10000FDB_anon.png: CAP (57.19%), bbox=(np.int64(53), np.int64(0), np.int64(511), np.int64(511))
# 10000FDC_anon.png: CAP (68.40%), bbox=(np.int64(52), np.int64(0), np.int64(511), np.int64(511))
# 10000FDD_anon.png: CAP (66.05%), bbox=(np.int64(52), np.int64(0), np.int64(511), np.int64(511))
# 10000FDE_anon.png: CAP (77.84%), bbox=(np.int64(56), np.int64(0), np.int64(511), np.int64(511))
# 10000FDF_anon.png: CAP (55.17%), bbox=(np.int64(52), np.int64(0), np.int64(511), np.int64(511))
# 10000FE0_anon.png: CAP (67.44%), bbox=(np.int64(53), np.int64(0), np.int64(511), np.int64(511))
# 10000FE1_anon.png: CAP (63.10%), bbox=(np.int64(52), np.int64(0), np.int64(511), np.int64(511))
# 10000FE2_anon.png: CAP (70.76%), bbox=(np.int64(65), np.int64(0), np.int64(511), np.int64(511))
# 10000FE3_anon.png: COVID-19 (50.02%), bbox=(np.int64(67), np.int64(183), np.int64(511), np.int64(373))
# 10000FE4_anon.png: CAP (58.86%), bbox=(np.int64(83), np.int64(0), np.int64(511), np.int64(511))
# 10000FE5_anon.png: CAP (78.98%), bbox=(np.int64(115), np.int64(0), np.int64(449), np.int64(472))
# 10000FE6_anon.png: CAP (83.57%), bbox=(np.int64(129), np.int64(0), np.int64(425), np.int64(454))
# 10000FE7_anon.png: CAP (61.95%), bbox=(np.int64(111), np.int64(0), np.int64(431), np.int64(511))
# 10000FE8_anon.png: CAP (75.86%), bbox=(np.int64(150), np.int64(0), np.int64(405), np.int64(451))
# ...
# CP_1153_3371_0084.png: CAP (100.00%), bbox=(np.int64(0), np.int64(160), np.int64(473), np.int64(457))
# CP_1153_3371_0085.png: CAP (100.00%), bbox=(np.int64(0), np.int64(144), np.int64(511), np.int64(425))
# CP_1153_3371_0086.png: CAP (100.00%), bbox=(np.int64(0), np.int64(171), np.int64(469), np.int64(449))
# CP_1153_3371_0087.png: CAP (100.00%), bbox=(np.int64(0), np.int64(182), np.int64(455), np.int64(444))
# CP_1153_3371_0088.png: CAP (100.00%), bbox=(np.int64(0), np.int64(184), np.int64(448), np.int64(454))
# normal_10 (2) - Copy.png: Normal (96.24%), bbox=(np.int64(101), np.int64(0), np.int64(269), np.int64(103))
# normal_10 (2).png: Normal (96.24%), bbox=(np.int64(101), np.int64(0), np.int64(269), np.int64(103))
# normal_10 - Copy (2) - Copy.png: Normal (98.04%), bbox=(np.int64(88), np.int64(0), np.int64(257), np.int64(107))
# normal_10 - Copy (2).png: Normal (98.04%), bbox=(np.int64(88), np.int64(0), np.int64(257), np.int64(107))
# normal_10 - Copy (3).png: Normal (99.37%), bbox=(np.int64(102), np.int64(0), np.int64(285), np.int64(105))
# normal_10 - Copy - Copy.png: Normal (99.33%), bbox=(np.int64(102), np.int64(0), np.int64(283), np.int64(105))
# normal_10 - Copy.png: Normal (99.33%), bbox=(np.int64(102), np.int64(0), np.int64(283), np.int64(105))
# normal_10.png: Normal (99.37%), bbox=(np.int64(102), np.int64(0), np.int64(285), np.int64(105))
# normal_11 (2) - Copy.png: Normal (99.98%), bbox=(np.int64(42), np.int64(128), np.int64(439), np.int64(344))
# normal_11 (2).png: Normal (99.98%), bbox=(np.int64(42), np.int64(128), np.int64(439), np.int64(344))
# normal_11 - Copy (2) - Copy.png: Normal (99.99%), bbox=(np.int64(40), np.int64(0), np.int64(440), np.int64(340))
# normal_11 - Copy (2).png: Normal (99.99%), bbox=(np.int64(40), np.int64(0), np.int64(440), np.int64(340))
# normal_11 - Copy (3).png: Normal (99.99%), bbox=(np.int64(41), np.int64(128), np.int64(439), np.int64(344))
# normal_11 - Copy - Copy.png: Normal (99.99%), bbox=(np.int64(44), np.int64(0), np.int64(440), np.int64(340))
# normal_11 - Copy.png: Normal (99.99%), bbox=(np.int64(44), np.int64(0), np.int64(440), np.int64(340))
# normal_11.png: Normal (99.99%), bbox=(np.int64(41), np.int64(128), np.int64(439), np.int64(344))
# normal_12 (2) - Copy.png: CAP (51.62%), bbox=(np.int64(162), np.int64(0), np.int64(618), np.int64(480))
# normal_12 (2).png: CAP (51.62%), bbox=(np.int64(162), np.int64(0), np.int64(618), np.int64(480))
# normal_12 - Copy (2) - Copy.png: COVID-19 (70.03%), bbox=(np.int64(0), np.int64(92), np.int64(433), np.int64(311))
# normal_12 - Copy (2).png: COVID-19 (70.03%), bbox=(np.int64(0), np.int64(92), np.int64(433), np.int64(311))
# normal_12 - Copy (3).png: COVID-19 (78.52%), bbox=(np.int64(0), np.int64(80), np.int64(497), np.int64(318))
# normal_12 - Copy - Copy.png: COVID-19 (63.14%), bbox=(np.int64(0), np.int64(84), np.int64(515), np.int64(312))
# normal_12 - Copy.png: COVID-19 (63.14%), bbox=(np.int64(0), np.int64(84), np.int64(515), np.int64(312))
# normal_12.png: COVID-19 (78.52%), bbox=(np.int64(0), np.int64(80), np.int64(497), np.int64(318))
# normal_13 (2) - Copy.png: CAP (97.65%), bbox=(np.int64(57), np.int64(0), np.int64(667), np.int64(516))
# normal_13 (2).png: CAP (97.65%), bbox=(np.int64(57), np.int64(0), np.int64(667), np.int64(516))
# normal_13 - Copy (2) - Copy.png: CAP (93.67%), bbox=(np.int64(0), np.int64(158), np.int64(664), np.int64(507))
# normal_13 - Copy (2).png: CAP (93.67%), bbox=(np.int64(0), np.int64(158), np.int64(664), np.int64(507))
# normal_13 - Copy (3).png: COVID-19 (93.63%), bbox=(np.int64(0), np.int64(0), np.int64(846), np.int64(532))
# normal_13 - Copy - Copy.png: COVID-19 (98.38%), bbox=(np.int64(0), np.int64(0), np.int64(846), np.int64(198))
# normal_13 - Copy.png: COVID-19 (98.38%), bbox=(np.int64(0), np.int64(0), np.int64(846), np.int64(198))
# normal_13.png: COVID-19 (93.63%), bbox=(np.int64(0), np.int64(0), np.int64(846), np.int64(532))
# normal_16 (2) - Copy.png: Normal (99.14%), bbox=(np.int64(104), np.int64(0), np.int64(280), np.int64(93))
# normal_16 (2).png: Normal (99.14%), bbox=(np.int64(104), np.int64(0), np.int64(280), np.int64(93))
# normal_16 - Copy (2) - Copy.png: COVID-19 (50.72%), bbox=(np.int64(239), np.int64(0), np.int64(278), np.int64(44))
# normal_16 - Copy (2).png: COVID-19 (50.72%), bbox=(np.int64(239), np.int64(0), np.int64(278), np.int64(44))
# normal_16 - Copy (3).png: Normal (99.40%), bbox=(np.int64(104), np.int64(0), np.int64(293), np.int64(93))
# normal_16 - Copy - Copy.png: Normal (99.13%), bbox=(np.int64(104), np.int64(0), np.int64(278), np.int64(93))
# normal_16 - Copy.png: Normal (99.13%), bbox=(np.int64(104), np.int64(0), np.int64(278), np.int64(93))
# normal_16.png: Normal (99.40%), bbox=(np.int64(104), np.int64(0), np.int64(293), np.int64(93))
# normal_17 (2) - Copy.png: COVID-19 (97.47%), bbox=(np.int64(0), np.int64(78), np.int64(542), np.int64(474))
# normal_17 (2).png: COVID-19 (97.47%), bbox=(np.int64(0), np.int64(78), np.int64(542), np.int64(474))
# normal_17 - Copy (2) - Copy.png: COVID-19 (72.11%), bbox=(np.int64(0), np.int64(237), np.int64(420), np.int64(424))
# normal_17 - Copy (2).png: COVID-19 (72.11%), bbox=(np.int64(0), np.int64(237), np.int64(420), np.int64(424))
# normal_17 - Copy (3).png: COVID-19 (98.07%), bbox=(np.int64(0), np.int64(79), np.int64(542), np.int64(474))
# normal_17 - Copy - Copy.png: COVID-19 (97.56%), bbox=(np.int64(0), np.int64(87), np.int64(542), np.int64(474))
# normal_17 - Copy.png: COVID-19 (97.56%), bbox=(np.int64(0), np.int64(87), np.int64(542), np.int64(474))
# normal_17.png: COVID-19 (98.07%), bbox=(np.int64(0), np.int64(79), np.int64(542), np.int64(474))
# normal_18 (2) - Copy.png: Normal (99.95%), bbox=(np.int64(57), np.int64(122), np.int64(437), np.int64(337))
# normal_18 (2).png: Normal (99.95%), bbox=(np.int64(57), np.int64(122), np.int64(437), np.int64(337))
# normal_18 - Copy (2) - Copy.png: Normal (99.97%), bbox=(np.int64(56), np.int64(117), np.int64(437), np.int64(337))
# normal_18 - Copy (2).png: Normal (99.97%), bbox=(np.int64(56), np.int64(117), np.int64(437), np.int64(337))
# normal_18 - Copy (3).png: Normal (99.97%), bbox=(np.int64(56), np.int64(116), np.int64(437), np.int64(337))
# normal_18 - Copy - Copy.png: Normal (99.97%), bbox=(np.int64(56), np.int64(116), np.int64(437), np.int64(337))
# normal_18 - Copy.png: Normal (99.97%), bbox=(np.int64(56), np.int64(116), np.int64(437), np.int64(337))
# normal_18.png: Normal (99.97%), bbox=(np.int64(56), np.int64(116), np.int64(437), np.int64(337))
# normal_19 (2) - Copy.png: Normal (99.36%), bbox=(np.int64(0), np.int64(55), np.int64(537), np.int64(418))
# normal_19 (2).png: Normal (99.36%), bbox=(np.int64(0), np.int64(55), np.int64(537), np.int64(418))
# normal_19 - Copy (2) - Copy.png: Normal (57.76%), bbox=(np.int64(90), np.int64(0), np.int64(342), np.int64(355))
# normal_19 - Copy (2).png: Normal (57.76%), bbox=(np.int64(90), np.int64(0), np.int64(342), np.int64(355))
# normal_19 - Copy (3).png: Normal (99.44%), bbox=(np.int64(0), np.int64(54), np.int64(537), np.int64(418))
# normal_19 - Copy - Copy.png: Normal (99.38%), bbox=(np.int64(0), np.int64(63), np.int64(537), np.int64(418))
# normal_19 - Copy.png: Normal (99.38%), bbox=(np.int64(0), np.int64(63), np.int64(537), np.int64(418))
# normal_19.png: Normal (99.44%), bbox=(np.int64(0), np.int64(54), np.int64(537), np.int64(418))
# normal_2 (2) - Copy.png: COVID-19 (51.29%), bbox=(np.int64(287), np.int64(219), np.int64(572), np.int64(478))
# normal_2 (2).png: COVID-19 (51.29%), bbox=(np.int64(287), np.int64(219), np.int64(572), np.int64(478))
# normal_2 - Copy (2) - Copy.png: CAP (63.24%), bbox=(np.int64(0), np.int64(0), np.int64(629), np.int64(431))
# normal_2 - Copy (2).png: CAP (63.24%), bbox=(np.int64(0), np.int64(0), np.int64(629), np.int64(431))
# normal_2 - Copy (3).png: CAP (59.60%), bbox=(np.int64(0), np.int64(0), np.int64(629), np.int64(425))
# normal_2 - Copy - Copy.png: CAP (63.24%), bbox=(np.int64(0), np.int64(0), np.int64(629), np.int64(431))
# normal_2 - Copy.png: CAP (63.24%), bbox=(np.int64(0), np.int64(0), np.int64(629), np.int64(431))
# normal_2.png: CAP (59.60%), bbox=(np.int64(0), np.int64(0), np.int64(629), np.int64(425))
# normal_20 (2) - Copy.png: Normal (98.85%), bbox=(np.int64(0), np.int64(71), np.int64(291), np.int64(247))
# normal_20 (2).png: Normal (98.85%), bbox=(np.int64(0), np.int64(71), np.int64(291), np.int64(247))
# normal_20 - Copy (2) - Copy.png: Normal (98.47%), bbox=(np.int64(0), np.int64(71), np.int64(280), np.int64(247))
# normal_20 - Copy (2).png: Normal (98.47%), bbox=(np.int64(0), np.int64(71), np.int64(280), np.int64(247))
# normal_20 - Copy (3).png: Normal (98.85%), bbox=(np.int64(0), np.int64(71), np.int64(291), np.int64(247))
# normal_20 - Copy - Copy.png: Normal (98.79%), bbox=(np.int64(0), np.int64(69), np.int64(285), np.int64(247))
# normal_20 - Copy.png: Normal (98.79%), bbox=(np.int64(0), np.int64(69), np.int64(285), np.int64(247))
# normal_20.png: Normal (98.85%), bbox=(np.int64(0), np.int64(71), np.int64(291), np.int64(247))
# normal_21 - Copy (2) - Copy.png: COVID-19 (80.14%), bbox=(np.int64(0), np.int64(112), np.int64(541), np.int64(345))
# normal_21 - Copy (2).png: COVID-19 (80.14%), bbox=(np.int64(0), np.int64(112), np.int64(541), np.int64(345))
# normal_21 - Copy - Copy.png: COVID-19 (80.14%), bbox=(np.int64(0), np.int64(112), np.int64(541), np.int64(345))
# normal_21 - Copy.png: COVID-19 (80.14%), bbox=(np.int64(0), np.int64(112), np.int64(541), np.int64(345))
# normal_3 (2) - Copy.png: Normal (98.96%), bbox=(np.int64(43), np.int64(38), np.int64(373), np.int64(343))
# normal_3 (2).png: Normal (98.96%), bbox=(np.int64(43), np.int64(38), np.int64(373), np.int64(343))
# normal_3 - Copy (2) - Copy.png: Normal (98.30%), bbox=(np.int64(37), np.int64(76), np.int64(373), np.int64(343))
# normal_3 - Copy (2).png: Normal (98.30%), bbox=(np.int64(37), np.int64(76), np.int64(373), np.int64(343))
# normal_3 - Copy (3).png: Normal (98.96%), bbox=(np.int64(43), np.int64(38), np.int64(373), np.int64(343))
# normal_3 - Copy - Copy.png: Normal (98.30%), bbox=(np.int64(37), np.int64(76), np.int64(373), np.int64(343))
# normal_3 - Copy.png: Normal (98.30%), bbox=(np.int64(37), np.int64(76), np.int64(373), np.int64(343))
# normal_3.png: Normal (98.96%), bbox=(np.int64(43), np.int64(38), np.int64(373), np.int64(343))
# normal_4 (2) - Copy.png: COVID-19 (91.39%), bbox=(np.int64(0), np.int64(0), np.int64(523), np.int64(333))
# normal_4 (2).png: COVID-19 (91.39%), bbox=(np.int64(0), np.int64(0), np.int64(523), np.int64(333))
# normal_4 - Copy (2) - Copy.png: COVID-19 (51.69%), bbox=(np.int64(0), np.int64(153), np.int64(382), np.int64(342))
# normal_4 - Copy (2).png: COVID-19 (51.69%), bbox=(np.int64(0), np.int64(153), np.int64(382), np.int64(342))
# normal_4 - Copy (3).png: COVID-19 (91.39%), bbox=(np.int64(0), np.int64(0), np.int64(523), np.int64(333))
# normal_4 - Copy - Copy.png: COVID-19 (51.69%), bbox=(np.int64(0), np.int64(153), np.int64(382), np.int64(342))
# normal_4 - Copy.png: COVID-19 (51.69%), bbox=(np.int64(0), np.int64(153), np.int64(382), np.int64(342))
# normal_4.png: COVID-19 (91.39%), bbox=(np.int64(0), np.int64(0), np.int64(523), np.int64(333))
# normal_5 (2) - Copy.png: CAP (88.61%), bbox=(np.int64(0), np.int64(0), np.int64(849), np.int64(505))
# normal_5 (2).png: CAP (88.61%), bbox=(np.int64(0), np.int64(0), np.int64(849), np.int64(505))
# normal_5 - Copy (2) - Copy.png: CAP (88.61%), bbox=(np.int64(0), np.int64(0), np.int64(849), np.int64(505))
# normal_5 - Copy (2).png: CAP (88.61%), bbox=(np.int64(0), np.int64(0), np.int64(849), np.int64(505))
# normal_5 - Copy (3).png: CAP (88.61%), bbox=(np.int64(0), np.int64(0), np.int64(849), np.int64(505))
# normal_5 - Copy - Copy.png: CAP (88.61%), bbox=(np.int64(0), np.int64(0), np.int64(849), np.int64(505))
# normal_5 - Copy.png: CAP (88.61%), bbox=(np.int64(0), np.int64(0), np.int64(849), np.int64(505))
# normal_5.png: CAP (88.61%), bbox=(np.int64(0), np.int64(0), np.int64(849), np.int64(505))
# normal_6 (2) - Copy.png: COVID-19 (100.00%), bbox=(np.int64(117), np.int64(324), np.int64(649), np.int64(551))
# normal_6 (2).png: COVID-19 (100.00%), bbox=(np.int64(117), np.int64(324), np.int64(649), np.int64(551))
# normal_6 - Copy (2) - Copy.png: COVID-19 (99.58%), bbox=(np.int64(0), np.int64(270), np.int64(531), np.int64(475))
# normal_6 - Copy (2).png: COVID-19 (99.58%), bbox=(np.int64(0), np.int64(270), np.int64(531), np.int64(475))
# normal_6 - Copy (3).png: COVID-19 (100.00%), bbox=(np.int64(117), np.int64(324), np.int64(649), np.int64(551))
# normal_6 - Copy - Copy.png: COVID-19 (99.58%), bbox=(np.int64(0), np.int64(270), np.int64(531), np.int64(475))
# normal_6 - Copy.png: COVID-19 (99.58%), bbox=(np.int64(0), np.int64(270), np.int64(531), np.int64(475))
# normal_6.png: COVID-19 (100.00%), bbox=(np.int64(117), np.int64(324), np.int64(649), np.int64(551))
# normal_7 (2) - Copy.png: COVID-19 (99.51%), bbox=(np.int64(73), np.int64(0), np.int64(939), np.int64(626))
# normal_7 (2).png: COVID-19 (99.51%), bbox=(np.int64(73), np.int64(0), np.int64(939), np.int64(626))
# normal_7 - Copy (2) - Copy.png: Normal (91.77%), bbox=(np.int64(185), np.int64(0), np.int64(483), np.int64(492))
# normal_7 - Copy (2).png: Normal (91.77%), bbox=(np.int64(185), np.int64(0), np.int64(483), np.int64(492))
# normal_7 - Copy (3).png: COVID-19 (99.51%), bbox=(np.int64(73), np.int64(0), np.int64(939), np.int64(626))
# normal_7 - Copy - Copy.png: Normal (91.77%), bbox=(np.int64(185), np.int64(0), np.int64(483), np.int64(492))
# normal_7 - Copy.png: Normal (91.77%), bbox=(np.int64(185), np.int64(0), np.int64(483), np.int64(492))
# normal_7.png: COVID-19 (99.51%), bbox=(np.int64(73), np.int64(0), np.int64(939), np.int64(626))
# normal_8 (2) - Copy.png: Normal (42.43%), bbox=(np.int64(243), np.int64(86), np.int64(577), np.int64(273))
# normal_8 (2).png: Normal (42.43%), bbox=(np.int64(243), np.int64(86), np.int64(577), np.int64(273))
# normal_8 - Copy (2) - Copy.png: CAP (53.79%), bbox=(np.int64(60), np.int64(401), np.int64(799), np.int64(576))
# normal_8 - Copy (2).png: CAP (53.79%), bbox=(np.int64(60), np.int64(401), np.int64(799), np.int64(576))
# normal_8 - Copy (3).png: Normal (41.27%), bbox=(np.int64(237), np.int64(91), np.int64(573), np.int64(274))
# normal_8 - Copy - Copy.png: CAP (53.79%), bbox=(np.int64(60), np.int64(401), np.int64(799), np.int64(576))
# normal_8 - Copy.png: CAP (53.79%), bbox=(np.int64(60), np.int64(401), np.int64(799), np.int64(576))
# normal_8.png: Normal (41.27%), bbox=(np.int64(237), np.int64(91), np.int64(573), np.int64(274))
# normal_n6 (2) - Copy.jpg: Normal (99.96%), bbox=(np.int64(56), np.int64(0), np.int64(189), np.int64(99))
# normal_n6 (2).jpg: Normal (99.96%), bbox=(np.int64(56), np.int64(0), np.int64(189), np.int64(99))
# normal_n6 - Copy.jpg: Normal (99.96%), bbox=(np.int64(56), np.int64(0), np.int64(189), np.int64(99))
# normal_n6.jpg: Normal (99.96%), bbox=(np.int64(56), np.int64(0), np.int64(189), np.int64(99))
# normal_n7 (2) - Copy.png: CAP (94.93%), bbox=(np.int64(143), np.int64(0), np.int64(553), np.int64(264))
# normal_n7 (2).png: CAP (94.93%), bbox=(np.int64(143), np.int64(0), np.int64(553), np.int64(264))
# normal_n7 - Copy.png: CAP (94.93%), bbox=(np.int64(143), np.int64(0), np.int64(553), np.int64(264))
# normal_n7.png: CAP (94.93%), bbox=(np.int64(143), np.int64(0), np.int64(553), np.int64(264))
# normal_n8 (2) - Copy.jpg: COVID-19 (100.00%), bbox=(np.int64(118), np.int64(325), np.int64(649), np.int64(551))
# normal_n8 (2).jpg: COVID-19 (100.00%), bbox=(np.int64(118), np.int64(325), np.int64(649), np.int64(551))
# normal_n8 - Copy.jpg: COVID-19 (100.00%), bbox=(np.int64(118), np.int64(325), np.int64(649), np.int64(551))
# normal_n8.jpg: COVID-19 (100.00%), bbox=(np.int64(118), np.int64(325), np.int64(649), np.int64(551))
# normal_n9 (2) - Copy.jpg: COVID-19 (98.73%), bbox=(np.int64(161), np.int64(217), np.int64(289), np.int64(357))
# normal_n9 (2).jpg: COVID-19 (98.73%), bbox=(np.int64(161), np.int64(217), np.int64(289), np.int64(357))
# normal_n9 - Copy.jpg: COVID-19 (98.73%), bbox=(np.int64(161), np.int64(217), np.int64(289), np.int64(357))
# normal_n9.jpg: COVID-19 (98.73%), bbox=(np.int64(161), np.int64(217), np.int64(289), np.int64(357))

# %%
import onnxruntime as ort

# %%
def export_to_onnx(model, onnx_file_path, input_shape=(1, 3, 224, 224)):
    """
    Экспортирует модель PyTorch в формат ONNX.

    Args:
        model (torch.nn.Module): Модель для экспорта.
        onnx_file_path (str): Путь, по которому будет сохранен ONNX-файл.
        input_shape (tuple): Ожидаемая форма входного тензора.
    """
    dummy_input = torch.randn(input_shape, requires_grad=True).to(device)
    torch.onnx.export(model,
                      dummy_input,
                      onnx_file_path,
                      export_params=True,
                      opset_version=11,
                      do_constant_folding=True,
                      input_names=['input'],
                      output_names=['output'],
                      dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}})
    print("Экспорт в ONNX завершен успешно!")
    print(f"Экспорт модели в ONNX формат: {onnx_file_path}")
    model.eval()

# %%
export_to_onnx(model, "densenet_ct.onnx")
# Out:
# Экспорт в ONNX завершен успешно!
# Экспорт модели в ONNX формат: densenet_ct.onnx
