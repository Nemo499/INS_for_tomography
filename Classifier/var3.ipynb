# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from torchvision.models import ResNet50_Weights # Импортируем ResNet50_Weights
import os

# 1. Определение преобразований для изображений
# Нормализация данных. Значения, основанные на ImageNet, подходят для предобученных моделей.
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
# 2. Загрузка данных
data_dir = r'C:\trainData\split' # Укажите путь к вашему датасету
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: DataLoader(image_datasets[x], batch_size=32,
                             shuffle=True, num_workers=4)
               for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 3. Использование предобученной модели (Transfer Learning)
# ResNet-18 - отличный выбор для начала
model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

# Заморозка всех слоев, кроме последнего, для сохранения обученных весов
for param in model.parameters():
    param.requires_grad = False

# Замена последнего полносвязного слоя на новый
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2) # У нас 2 класса: 'pathology' и 'no_pathology'

model = model.to(device)

if torch.cuda.is_available():
    print("GPU доступен. Используется:", torch.cuda.get_device_name(0))
    print("Количество GPU:", torch.cuda.device_count())
    device = torch.device("cuda:0")
else:
    print("GPU не найден. Обучение будет на CPU.")
    device = torch.device("cpu")

print(torch.version.cuda)
# Out:
# GPU доступен. Используется: NVIDIA GeForce RTX 2070
# Количество GPU: 1
# 12.1

# %%
import copy
# 4. Определение функции потерь, оптимизатора и планировщика
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)
# Планировщик будет уменьшать lr в 10 раз каждые 7 эпох
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# 5. Функция обучения (с Early Stopping)
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    best_acc = 0.0
    best_model_wts = copy.deepcopy(model.state_dict())
    
    # Параметры Early Stopping
    epochs_no_improve = 0
    n_epochs_stop = 50
    
    for epoch in range(num_epochs):
        print(f'Эпоха {epoch}/{num_epochs - 1}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            
            # Обновление планировщика только на этапе обучения
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Потери: {epoch_loss:.4f} Точность: {epoch_acc:.4f}')

            # Ранняя остановка и сохранение лучшей модели
            if phase == 'val':
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                    epochs_no_improve = 0
                else:
                    epochs_no_improve += 1
                
                if epochs_no_improve >= n_epochs_stop:
                    print('Ранняя остановка! Обучение завершено.')
                    model.load_state_dict(best_model_wts)
                    torch.save(model.state_dict(), 'best_model_weights.pt')
                    return model

    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'best_model_weights.pt')
    return model

# 6. Запуск обучения
trained_model = train_model(model, criterion, optimizer, scheduler, num_epochs=50)
# Out:
# Эпоха 0/49
# ----------
# train Потери: 0.3324 Точность: 0.8739
# val Потери: 0.2673 Точность: 0.9120
# Эпоха 1/49
# ----------
# train Потери: 0.2483 Точность: 0.9077
# val Потери: 0.2423 Точность: 0.9195
# Эпоха 2/49
# ----------
# train Потери: 0.2245 Точность: 0.9168
# val Потери: 0.2133 Точность: 0.9204
# Эпоха 3/49
# ----------
# train Потери: 0.2134 Точность: 0.9240
# val Потери: 0.2065 Точность: 0.9190
# Эпоха 4/49
# ----------
# train Потери: 0.1992 Точность: 0.9302
# val Потери: 0.1996 Точность: 0.9260
# Эпоха 5/49
# ----------
# train Потери: 0.1900 Точность: 0.9327
# val Потери: 0.2221 Точность: 0.9330
# Эпоха 6/49
# ----------
# train Потери: 0.1854 Точность: 0.9334
# val Потери: 0.1927 Точность: 0.9309
# Эпоха 7/49
# ----------
# train Потери: 0.1721 Точность: 0.9379
# val Потери: 0.1865 Точность: 0.9291
# Эпоха 8/49
# ----------
# train Потери: 0.1752 Точность: 0.9389
# val Потери: 0.1885 Точность: 0.9330
# Эпоха 9/49
# ----------
# train Потери: 0.1761 Точность: 0.9367
# val Потери: 0.1798 Точность: 0.9313
# Эпоха 10/49
# ----------
# train Потери: 0.1734 Точность: 0.9396
# val Потери: 0.2084 Точность: 0.9151
# Ранняя остановка! Обучение завершено.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from torchvision.models import ResNet50_Weights
import os
import copy

# 1. Определение преобразований с улучшенной аугментацией
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15), 
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
        # --- Добавленные методы аугментации ---
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1), # Изменение цвета
        transforms.RandomPerspective(distortion_scale=0.3, p=0.5), # Изменение перспективы
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# 2. Загрузка данных
data_dir = r'C:\trainData\split'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: DataLoader(image_datasets[x], batch_size=32,
                              shuffle=True, num_workers=4)
               for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

# 3. Настройка GPU/CPU
if torch.cuda.is_available():
    print("GPU доступен. Используется:", torch.cuda.get_device_name(0))
    print("Количество GPU:", torch.cuda.device_count())
    device = torch.device("cuda:0")
else:
    print("GPU не найден. Обучение будет на CPU.")
    device = torch.device("cpu")
print(f"Версия CUDA: {torch.version.cuda}")

# 4. Использование предобученной модели (ResNet-50)
model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

for param in model.parameters():
    param.requires_grad = False

for param in model.layer4.parameters():
    param.requires_grad = True

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model = model.to(device)

# 5. Определение функции потерь, оптимизатора и планировщика
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# 6. Функция обучения (с Early Stopping)
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    best_acc = 0.0
    best_model_wts = copy.deepcopy(model.state_dict())
    
    epochs_no_improve = 0
    n_epochs_stop = 10
    
    for epoch in range(num_epochs):
        print(f'Эпоха {epoch}/{num_epochs - 1}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Потери: {epoch_loss:.4f} Точность: {epoch_acc:.4f}')

            if phase == 'val':
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = copy.deepcopy(model.state_dict())
                    epochs_no_improve = 0
                else:
                    epochs_no_improve += 1
                
                if epochs_no_improve >= n_epochs_stop:
                    print('Ранняя остановка! Обучение завершено.')
                    model.load_state_dict(best_model_wts)
                    torch.save(model.state_dict(), 'best_model_weights.pt')
                    return model

    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(), 'best_model_weights.pt')
    return model

# 7. Запуск обучения
trained_model = train_model(model, criterion, optimizer, scheduler, num_epochs=70)
# Out:
# GPU доступен. Используется: NVIDIA GeForce RTX 2070
# Количество GPU: 1
# Версия CUDA: 12.1
# Эпоха 0/69
# ----------
# train Потери: 0.1992 Точность: 0.9269
# val Потери: 0.1420 Точность: 0.9497
# Эпоха 1/69
# ----------
# train Потери: 0.1305 Точность: 0.9574
# val Потери: 0.1242 Точность: 0.9615
# Эпоха 2/69
# ----------
# train Потери: 0.1107 Точность: 0.9648
# val Потери: 0.1424 Точность: 0.9606
# Эпоха 3/69
# ----------
# train Потери: 0.1007 Точность: 0.9674
# val Потери: 0.1003 Точность: 0.9650
# Эпоха 4/69
# ----------
# train Потери: 0.0902 Точность: 0.9709
# val Потери: 0.0925 Точность: 0.9711
# Эпоха 5/69
# ----------
# train Потери: 0.0874 Точность: 0.9708
# val Потери: 0.0913 Точность: 0.9689
# Эпоха 6/69
# ----------
# train Потери: 0.0838 Точность: 0.9720
# val Потери: 0.0732 Точность: 0.9742
# Эпоха 7/69
# ----------
# train Потери: 0.0592 Точность: 0.9805
# val Потери: 0.0723 Точность: 0.9768
# Эпоха 8/69
# ----------
# train Потери: 0.0567 Точность: 0.9815
# val Потери: 0.0770 Точность: 0.9781
# Эпоха 9/69
# ----------
# train Потери: 0.0466 Точность: 0.9847
# val Потери: 0.0688 Точность: 0.9786
# Эпоха 10/69
# ----------
# train Потери: 0.0487 Точность: 0.9831
# val Потери: 0.0714 Точность: 0.9790
# Эпоха 11/69
# ----------
# train Потери: 0.0459 Точность: 0.9836
# val Потери: 0.0650 Точность: 0.9786
# Эпоха 12/69
# ----------
# train Потери: 0.0405 Точность: 0.9855
# val Потери: 0.0623 Точность: 0.9794
# Эпоха 13/69
# ----------
# train Потери: 0.0382 Точность: 0.9873
# val Потери: 0.0617 Точность: 0.9812
# Эпоха 14/69
# ----------
# train Потери: 0.0387 Точность: 0.9861
# val Потери: 0.0614 Точность: 0.9803
# Эпоха 15/69
# ----------
# train Потери: 0.0380 Точность: 0.9879
# val Потери: 0.0615 Точность: 0.9812
# Эпоха 16/69
# ----------
# train Потери: 0.0358 Точность: 0.9888
# val Потери: 0.0614 Точность: 0.9803
# Эпоха 17/69
# ----------
# train Потери: 0.0392 Точность: 0.9881
# val Потери: 0.0625 Точность: 0.9803
# Эпоха 18/69
# ----------
# train Потери: 0.0369 Точность: 0.9873
# val Потери: 0.0598 Точность: 0.9816
# Эпоха 19/69
# ----------
# train Потери: 0.0357 Точность: 0.9873
# val Потери: 0.0625 Точность: 0.9807
# Эпоха 20/69
# ----------
# train Потери: 0.0361 Точность: 0.9879
# val Потери: 0.0607 Точность: 0.9799
# Эпоха 21/69
# ----------
# train Потери: 0.0362 Точность: 0.9878
# val Потери: 0.0591 Точность: 0.9825
# Эпоха 22/69
# ----------
# train Потери: 0.0324 Точность: 0.9892
# val Потери: 0.0602 Точность: 0.9803
# Эпоха 23/69
# ----------
# train Потери: 0.0374 Точность: 0.9873
# val Потери: 0.0600 Точность: 0.9803
# Эпоха 24/69
# ----------
# train Потери: 0.0343 Точность: 0.9881
# val Потери: 0.0610 Точность: 0.9799
# Эпоха 25/69
# ----------
# train Потери: 0.0287 Точность: 0.9913
# val Потери: 0.0613 Точность: 0.9807
# Эпоха 26/69
# ----------
# train Потери: 0.0331 Точность: 0.9888
# val Потери: 0.0589 Точность: 0.9812
# Эпоха 27/69
# ----------
# train Потери: 0.0346 Точность: 0.9873
# val Потери: 0.0628 Точность: 0.9786
# Эпоха 28/69
# ----------
# train Потери: 0.0378 Точность: 0.9874
# val Потери: 0.0604 Точность: 0.9799
# Эпоха 29/69
# ----------
# train Потери: 0.0361 Точность: 0.9871
# val Потери: 0.0596 Точность: 0.9812
# Эпоха 30/69
# ----------
# train Потери: 0.0377 Точность: 0.9859
# val Потери: 0.0603 Точность: 0.9821
# Эпоха 31/69
# ----------
# train Потери: 0.0339 Точность: 0.9889
# val Потери: 0.0592 Точность: 0.9816
# Ранняя остановка! Обучение завершено.

# %%
torch.save(model.state_dict(), r"C:\trainData\split\VAR3.pth")

# %%
import torch
import torch.nn as nn
from torchvision import models
from torchvision.models import ResNet18_Weights

# Инициализация той же архитектуры модели
model_path = r"C:\trainData\split\VAR3.pth"  # Путь к вашему файлу с весами
model = models.resnet18(weights=ResNet18_Weights.DEFAULT)

# Заменяем последний слой, как и при обучении
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Загружаем сохранённые веса
model.load_state_dict(torch.load(model_path))
model.eval()  # Переводим модель в режим оценки

# %%
import os
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Преобразования для инференса
inference_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Путь к папке с изображениями для предсказания
inference_dir = r"C:\testData\norma_anon\postDICOM"
inference_dataset = datasets.ImageFolder(inference_dir, inference_transforms)
inference_loader = DataLoader(inference_dataset, batch_size=32, shuffle=False)

# Убедитесь, что классы соответствуют тем, на которых обучалась модель

# %%
from PIL import Image
# 2. Подготовка преобразований для одного изображения (без изменений)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# 3. Путь к папке с изображениями для предсказания (без изменений)
image_folder_path = r"C:\testData\pneumonia_anon\ostDICOM_black"

# Имена классов, в том же порядке, что и при обучении
class_names = [ 'pathology', 'no_pathology']

pathology_count = 0
no_pathology_count = 0
pathology_confidence_sum = 0.0
no_pathology_confidence_sum = 0.0
total_images = 0

# 4. Проход по каждому изображению и получение предсказания
with torch.no_grad():
    for filename in os.listdir(image_folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(image_folder_path, filename)
            
            try:
                image = Image.open(image_path).convert('RGB')
                image = transform(image).unsqueeze(0).to(device)
                outputs = model(image)
                
                probabilities = torch.nn.functional.softmax(outputs, dim=1)[0]
                
                confidence, predicted_class_index = torch.max(probabilities, 0)
                predicted_class_name = class_names[predicted_class_index.item()]
                confidence_score = confidence.item()

                print(f"Изображение: {filename}, Предсказанный класс: {predicted_class_name}, Уверенность: {confidence_score * 100:.2f}%")

                # Увеличение счетчиков и сумм уверенности
                if predicted_class_name == 'pathology':
                    pathology_count += 1
                    pathology_confidence_sum += confidence_score
                else:
                    no_pathology_count += 1
                    no_pathology_confidence_sum += confidence_score
                total_images += 1
            
            except Exception as e:
                print(f"Не удалось обработать файл {filename}. Ошибка: {e}")

# 5. Вывод итоговой статистики
print("\n--- Результаты классификации ---")
print(f"Всего обработано изображений: {total_images}")
print(f"Изображений с патологией: {pathology_count}")
print(f"Изображений без патологии: {no_pathology_count}")

# Расчет и вывод средней уверенности
if pathology_count > 0:
    avg_pathology_confidence = pathology_confidence_sum / pathology_count
    print(f"Средняя уверенность для класса 'pathology': {avg_pathology_confidence * 100:.2f}%")
else:
    print("Изображения с патологией не найдены.")

if no_pathology_count > 0:
    avg_no_pathology_confidence = no_pathology_confidence_sum / no_pathology_count
    print(f"Средняя уверенность для класса 'no_pathology': {avg_no_pathology_confidence * 100:.2f}%")
else:
    print("Изображения без патологии не найдены.")
# Out:
# Изображение: 1000032A_anon.png, Предсказанный класс: pathology, Уверенность: 88.60%
# Изображение: 1000032B_anon.png, Предсказанный класс: pathology, Уверенность: 78.82%
# Изображение: 1000032C_anon.png, Предсказанный класс: pathology, Уверенность: 78.35%
# Изображение: 1000032D_anon.png, Предсказанный класс: pathology, Уверенность: 59.34%
# Изображение: 1000032E_anon.png, Предсказанный класс: pathology, Уверенность: 86.40%
# Изображение: 1000032F_anon.png, Предсказанный класс: pathology, Уверенность: 93.38%
# Изображение: 10000330_anon.png, Предсказанный класс: pathology, Уверенность: 97.70%
# Изображение: 10000331_anon.png, Предсказанный класс: pathology, Уверенность: 94.21%
# Изображение: 10000332_anon.png, Предсказанный класс: pathology, Уверенность: 90.78%
# Изображение: 10000333_anon.png, Предсказанный класс: pathology, Уверенность: 90.91%
# Изображение: 10000334_anon.png, Предсказанный класс: pathology, Уверенность: 79.20%
# Изображение: 10000335_anon.png, Предсказанный класс: no_pathology, Уверенность: 55.25%
# Изображение: 10000336_anon.png, Предсказанный класс: no_pathology, Уверенность: 71.76%
# Изображение: 10000337_anon.png, Предсказанный класс: no_pathology, Уверенность: 79.29%
# Изображение: 10000338_anon.png, Предсказанный класс: pathology, Уверенность: 74.34%
# Изображение: 10000339_anon.png, Предсказанный класс: pathology, Уверенность: 84.27%
# Изображение: 1000033A_anon.png, Предсказанный класс: pathology, Уверенность: 99.59%
# Изображение: 1000033B_anon.png, Предсказанный класс: pathology, Уверенность: 99.85%
# Изображение: 1000033C_anon.png, Предсказанный класс: pathology, Уверенность: 99.93%
# Изображение: 1000033D_anon.png, Предсказанный класс: pathology, Уверенность: 99.83%
# Изображение: 1000033E_anon.png, Предсказанный класс: pathology, Уверенность: 99.86%
# Изображение: 1000033F_anon.png, Предсказанный класс: pathology, Уверенность: 99.86%
# Изображение: 10000340_anon.png, Предсказанный класс: pathology, Уверенность: 99.88%
# Изображение: 10000341_anon.png, Предсказанный класс: pathology, Уверенность: 99.98%
# Изображение: 10000342_anon.png, Предсказанный класс: pathology, Уверенность: 99.99%
# Изображение: 10000343_anon.png, Предсказанный класс: pathology, Уверенность: 99.99%
# Изображение: 10000344_anon.png, Предсказанный класс: pathology, Уверенность: 99.99%
# Изображение: 10000345_anon.png, Предсказанный класс: pathology, Уверенность: 99.85%
# Изображение: 10000346_anon.png, Предсказанный класс: pathology, Уверенность: 99.87%
# Изображение: 10000347_anon.png, Предсказанный класс: pathology, Уверенность: 99.98%
# Изображение: 10000348_anon.png, Предсказанный класс: pathology, Уверенность: 99.98%
# Изображение: 10000349_anon.png, Предсказанный класс: pathology, Уверенность: 99.88%
# Изображение: 1000034A_anon.png, Предсказанный класс: pathology, Уверенность: 99.91%
# Изображение: 1000034B_anon.png, Предсказанный класс: pathology, Уверенность: 99.88%
# Изображение: 1000034C_anon.png, Предсказанный класс: pathology, Уверенность: 99.93%
# Изображение: 1000034D_anon.png, Предсказанный класс: pathology, Уверенность: 99.99%
# Изображение: 1000034E_anon.png, Предсказанный класс: pathology, Уверенность: 99.92%
# Изображение: 1000034F_anon.png, Предсказанный класс: pathology, Уверенность: 99.86%
# Изображение: 10000350_anon.png, Предсказанный класс: pathology, Уверенность: 99.83%
# Изображение: 10000351_anon.png, Предсказанный класс: pathology, Уверенность: 98.90%
# Изображение: 10000352_anon.png, Предсказанный класс: pathology, Уверенность: 99.84%
# Изображение: 10000353_anon.png, Предсказанный класс: pathology, Уверенность: 99.51%
# Изображение: 10000354_anon.png, Предсказанный класс: pathology, Уверенность: 99.61%
# Изображение: 10000355_anon.png, Предсказанный класс: pathology, Уверенность: 98.85%
# Изображение: 10000356_anon.png, Предсказанный класс: pathology, Уверенность: 99.79%
# Изображение: 10000357_anon.png, Предсказанный класс: pathology, Уверенность: 98.10%
# Изображение: 10000358_anon.png, Предсказанный класс: pathology, Уверенность: 97.37%
# Изображение: 10000359_anon.png, Предсказанный класс: pathology, Уверенность: 98.45%
# Изображение: 1000035A_anon.png, Предсказанный класс: pathology, Уверенность: 99.59%
# Изображение: 1000035B_anon.png, Предсказанный класс: pathology, Уверенность: 98.61%
# Изображение: 1000035C_anon.png, Предсказанный класс: pathology, Уверенность: 97.95%
# Изображение: 1000035D_anon.png, Предсказанный класс: pathology, Уверенность: 98.06%
# Изображение: 1000035E_anon.png, Предсказанный класс: pathology, Уверенность: 97.63%
# Изображение: 1000035F_anon.png, Предсказанный класс: pathology, Уверенность: 90.82%
# Изображение: 10000360_anon.png, Предсказанный класс: pathology, Уверенность: 96.16%
# Изображение: 10000361_anon.png, Предсказанный класс: pathology, Уверенность: 99.01%
# Изображение: 10000362_anon.png, Предсказанный класс: pathology, Уверенность: 99.78%
# Изображение: 10000363_anon.png, Предсказанный класс: pathology, Уверенность: 99.32%
# Изображение: 10000364_anon.png, Предсказанный класс: pathology, Уверенность: 96.88%
# Изображение: 10000365_anon.png, Предсказанный класс: pathology, Уверенность: 97.87%
# Изображение: 10000366_anon.png, Предсказанный класс: pathology, Уверенность: 97.26%
# Изображение: 10000367_anon.png, Предсказанный класс: pathology, Уверенность: 99.59%
# Изображение: 10000368_anon.png, Предсказанный класс: pathology, Уверенность: 99.13%
# Изображение: 10000369_anon.png, Предсказанный класс: pathology, Уверенность: 88.95%
# Изображение: 1000036A_anon.png, Предсказанный класс: pathology, Уверенность: 97.01%
# Изображение: 1000036B_anon.png, Предсказанный класс: pathology, Уверенность: 99.07%
# Изображение: 1000036C_anon.png, Предсказанный класс: pathology, Уверенность: 99.33%
# Изображение: 1000036D_anon.png, Предсказанный класс: pathology, Уверенность: 99.50%
# Изображение: 1000036E_anon.png, Предсказанный класс: pathology, Уверенность: 99.20%
# Изображение: 1000036F_anon.png, Предсказанный класс: pathology, Уверенность: 99.79%
# Изображение: 10000370_anon.png, Предсказанный класс: pathology, Уверенность: 99.34%
# Изображение: 10000371_anon.png, Предсказанный класс: pathology, Уверенность: 99.65%
# Изображение: 10000372_anon.png, Предсказанный класс: pathology, Уверенность: 99.90%
# Изображение: 10000373_anon.png, Предсказанный класс: pathology, Уверенность: 99.83%
# Изображение: 10000374_anon.png, Предсказанный класс: pathology, Уверенность: 99.68%
# Изображение: 10000375_anon.png, Предсказанный класс: pathology, Уверенность: 99.83%
# Изображение: 10000376_anon.png, Предсказанный класс: pathology, Уверенность: 99.96%
# Изображение: 10000377_anon.png, Предсказанный класс: pathology, Уверенность: 99.75%
# Изображение: 10000378_anon.png, Предсказанный класс: pathology, Уверенность: 99.76%
# Изображение: 10000379_anon.png, Предсказанный класс: pathology, Уверенность: 99.81%
# Изображение: 1000037A_anon.png, Предсказанный класс: pathology, Уверенность: 98.50%
# Изображение: 1000037B_anon.png, Предсказанный класс: pathology, Уверенность: 99.02%
# Изображение: 1000037C_anon.png, Предсказанный класс: pathology, Уверенность: 99.34%
# Изображение: 1000037D_anon.png, Предсказанный класс: pathology, Уверенность: 99.78%
# Изображение: 1000037E_anon.png, Предсказанный класс: pathology, Уверенность: 99.86%
# Изображение: 1000037F_anon.png, Предсказанный класс: pathology, Уверенность: 99.43%
# Изображение: 10000380_anon.png, Предсказанный класс: pathology, Уверенность: 99.56%
# Изображение: 10000381_anon.png, Предсказанный класс: pathology, Уверенность: 99.38%
# Изображение: 10000382_anon.png, Предсказанный класс: pathology, Уверенность: 99.24%
# Изображение: 10000383_anon.png, Предсказанный класс: pathology, Уверенность: 99.44%
# Изображение: 10000384_anon.png, Предсказанный класс: pathology, Уверенность: 99.50%
# Изображение: 10000385_anon.png, Предсказанный класс: pathology, Уверенность: 99.27%
# Изображение: 10000386_anon.png, Предсказанный класс: pathology, Уверенность: 99.07%
# Изображение: 10000387_anon.png, Предсказанный класс: pathology, Уверенность: 99.23%
# Изображение: 10000388_anon.png, Предсказанный класс: pathology, Уверенность: 99.69%
# Изображение: 10000389_anon.png, Предсказанный класс: pathology, Уверенность: 98.94%
# Изображение: 1000038A_anon.png, Предсказанный класс: pathology, Уверенность: 99.43%
# Изображение: 1000038B_anon.png, Предсказанный класс: pathology, Уверенность: 99.29%
# Изображение: 1000038C_anon.png, Предсказанный класс: pathology, Уверенность: 98.29%
# Изображение: 1000038D_anon.png, Предсказанный класс: pathology, Уверенность: 98.92%
# Изображение: 1000038E_anon.png, Предсказанный класс: pathology, Уверенность: 98.92%
# Изображение: 1000038F_anon.png, Предсказанный класс: pathology, Уверенность: 99.34%
# Изображение: 10000390_anon.png, Предсказанный класс: pathology, Уверенность: 98.80%
# Изображение: 10000391_anon.png, Предсказанный класс: pathology, Уверенность: 99.28%
# Изображение: 10000392_anon.png, Предсказанный класс: pathology, Уверенность: 99.81%
# Изображение: 10000393_anon.png, Предсказанный класс: pathology, Уверенность: 99.48%
# Изображение: 10000394_anon.png, Предсказанный класс: pathology, Уверенность: 99.58%
# Изображение: 10000395_anon.png, Предсказанный класс: pathology, Уверенность: 99.25%
# Изображение: 10000396_anon.png, Предсказанный класс: pathology, Уверенность: 99.27%
# Изображение: 10000397_anon.png, Предсказанный класс: pathology, Уверенность: 99.75%
# Изображение: 10000398_anon.png, Предсказанный класс: pathology, Уверенность: 99.46%
# Изображение: 10000399_anon.png, Предсказанный класс: pathology, Уверенность: 99.53%
# Изображение: 1000039A_anon.png, Предсказанный класс: pathology, Уверенность: 97.08%
# Изображение: 1000039B_anon.png, Предсказанный класс: pathology, Уверенность: 93.96%
# Изображение: 1000039C_anon.png, Предсказанный класс: pathology, Уверенность: 91.41%
# Изображение: 1000039D_anon.png, Предсказанный класс: pathology, Уверенность: 73.83%
# Изображение: 1000039E_anon.png, Предсказанный класс: pathology, Уверенность: 84.26%
# Изображение: 1000039F_anon.png, Предсказанный класс: pathology, Уверенность: 88.26%
# Изображение: 100003A0_anon.png, Предсказанный класс: pathology, Уверенность: 96.53%
# Изображение: 100003A1_anon.png, Предсказанный класс: pathology, Уверенность: 98.45%
# Изображение: 100003A2_anon.png, Предсказанный класс: pathology, Уверенность: 97.76%
# Изображение: 100003A3_anon.png, Предсказанный класс: pathology, Уверенность: 97.42%
# Изображение: 100003A4_anon.png, Предсказанный класс: pathology, Уверенность: 95.71%
# Изображение: 100003A5_anon.png, Предсказанный класс: pathology, Уверенность: 94.14%
# Изображение: 100003A6_anon.png, Предсказанный класс: pathology, Уверенность: 90.65%
# Изображение: 100003A7_anon.png, Предсказанный класс: pathology, Уверенность: 87.04%
# Изображение: 100003A8_anon.png, Предсказанный класс: pathology, Уверенность: 82.85%
# Изображение: 100003A9_anon.png, Предсказанный класс: pathology, Уверенность: 80.48%
# Изображение: 100003AA_anon.png, Предсказанный класс: pathology, Уверенность: 87.23%
# Изображение: 100003AB_anon.png, Предсказанный класс: pathology, Уверенность: 94.13%
# Изображение: 100003AC_anon.png, Предсказанный класс: pathology, Уверенность: 80.53%
# Изображение: 100003AD_anon.png, Предсказанный класс: pathology, Уверенность: 86.89%
# Изображение: 100003AE_anon.png, Предсказанный класс: pathology, Уверенность: 96.03%
# Изображение: 100003AF_anon.png, Предсказанный класс: pathology, Уверенность: 95.26%
# Изображение: 100003B0_anon.png, Предсказанный класс: pathology, Уверенность: 93.66%
# Изображение: 100003B1_anon.png, Предсказанный класс: pathology, Уверенность: 90.35%
# Изображение: 100003B2_anon.png, Предсказанный класс: pathology, Уверенность: 84.14%
# Изображение: 100003B3_anon.png, Предсказанный класс: pathology, Уверенность: 52.05%
# Изображение: 100003B4_anon.png, Предсказанный класс: pathology, Уверенность: 62.51%
# Изображение: 100003B5_anon.png, Предсказанный класс: pathology, Уверенность: 55.53%
# Изображение: 100003B6_anon.png, Предсказанный класс: no_pathology, Уверенность: 65.25%
# Изображение: 100003B7_anon.png, Предсказанный класс: pathology, Уверенность: 77.16%
# Изображение: 100003B8_anon.png, Предсказанный класс: pathology, Уверенность: 82.80%
# Изображение: 100003B9_anon.png, Предсказанный класс: pathology, Уверенность: 64.96%
# Изображение: 100003BA_anon.png, Предсказанный класс: pathology, Уверенность: 62.17%
# Изображение: 100003BB_anon.png, Предсказанный класс: pathology, Уверенность: 67.03%
# Изображение: 100003BC_anon.png, Предсказанный класс: pathology, Уверенность: 89.51%
# Изображение: 100003BD_anon.png, Предсказанный класс: pathology, Уверенность: 99.53%
# Изображение: 100003BE_anon.png, Предсказанный класс: pathology, Уверенность: 92.64%
# Изображение: 100003BF_anon.png, Предсказанный класс: pathology, Уверенность: 99.10%
# Изображение: 100003C0_anon.png, Предсказанный класс: pathology, Уверенность: 85.93%
# Изображение: 100003C1_anon.png, Предсказанный класс: pathology, Уверенность: 88.07%
# Изображение: 100003C2_anon.png, Предсказанный класс: no_pathology, Уверенность: 50.44%
# Изображение: 100003C3_anon.png, Предсказанный класс: no_pathology, Уверенность: 70.88%
# Изображение: 100003C4_anon.png, Предсказанный класс: no_pathology, Уверенность: 60.59%
# Изображение: 100003C5_anon.png, Предсказанный класс: pathology, Уверенность: 78.07%
# Изображение: 100003C6_anon.png, Предсказанный класс: pathology, Уверенность: 91.88%
# Изображение: 100003C7_anon.png, Предсказанный класс: pathology, Уверенность: 60.13%
# Изображение: 100003C8_anon.png, Предсказанный класс: pathology, Уверенность: 75.90%
# Изображение: 100003C9_anon.png, Предсказанный класс: pathology, Уверенность: 55.60%
# Изображение: 100003CA_anon.png, Предсказанный класс: pathology, Уверенность: 66.20%
# Изображение: 100003CB_anon.png, Предсказанный класс: pathology, Уверенность: 81.43%
# Изображение: 100003CC_anon.png, Предсказанный класс: pathology, Уверенность: 52.33%
# Изображение: 100003CD_anon.png, Предсказанный класс: no_pathology, Уверенность: 82.59%
# Изображение: 100003CE_anon.png, Предсказанный класс: no_pathology, Уверенность: 84.72%
# Изображение: 100003CF_anon.png, Предсказанный класс: no_pathology, Уверенность: 71.35%
# Изображение: 100003D0_anon.png, Предсказанный класс: no_pathology, Уверенность: 80.82%
# Изображение: 100003D1_anon.png, Предсказанный класс: no_pathology, Уверенность: 71.13%
# Изображение: 100003D2_anon.png, Предсказанный класс: no_pathology, Уверенность: 89.77%
# Изображение: 100003D3_anon.png, Предсказанный класс: no_pathology, Уверенность: 52.91%
# Изображение: 100003D4_anon.png, Предсказанный класс: pathology, Уверенность: 71.74%
# Изображение: 100003D5_anon.png, Предсказанный класс: no_pathology, Уверенность: 91.39%
# Изображение: 100003D6_anon.png, Предсказанный класс: no_pathology, Уверенность: 91.34%
# Изображение: 100003D7_anon.png, Предсказанный класс: no_pathology, Уверенность: 93.03%
# Изображение: 100003D8_anon.png, Предсказанный класс: no_pathology, Уверенность: 93.34%
# Изображение: 100003D9_anon.png, Предсказанный класс: no_pathology, Уверенность: 92.29%
# Изображение: 100003DA_anon.png, Предсказанный класс: no_pathology, Уверенность: 92.99%
# Изображение: 100003DB_anon.png, Предсказанный класс: no_pathology, Уверенность: 82.08%
# Изображение: 100003DC_anon.png, Предсказанный класс: no_pathology, Уверенность: 88.57%
# Изображение: 100003DD_anon.png, Предсказанный класс: no_pathology, Уверенность: 93.16%
# Изображение: 100003DE_anon.png, Предсказанный класс: no_pathology, Уверенность: 95.26%
# Изображение: 100003DF_anon.png, Предсказанный класс: no_pathology, Уверенность: 96.02%
# Изображение: 100003E0_anon.png, Предсказанный класс: no_pathology, Уверенность: 93.10%
# Изображение: 100003E1_anon.png, Предсказанный класс: no_pathology, Уверенность: 86.99%
# Изображение: 100003E2_anon.png, Предсказанный класс: no_pathology, Уверенность: 68.83%
# Изображение: 100003E3_anon.png, Предсказанный класс: no_pathology, Уверенность: 74.77%
# Изображение: 100003E4_anon.png, Предсказанный класс: no_pathology, Уверенность: 52.90%
# Изображение: 100003E5_anon.png, Предсказанный класс: no_pathology, Уверенность: 54.93%
# Изображение: 100003E6_anon.png, Предсказанный класс: no_pathology, Уверенность: 57.98%
# Изображение: 100003E7_anon.png, Предсказанный класс: no_pathology, Уверенность: 58.29%
# Изображение: 100003E8_anon.png, Предсказанный класс: no_pathology, Уверенность: 70.85%
# Изображение: 100003E9_anon.png, Предсказанный класс: no_pathology, Уверенность: 73.88%
# Изображение: 100003EA_anon.png, Предсказанный класс: no_pathology, Уверенность: 76.69%
# Изображение: 100003EB_anon.png, Предсказанный класс: no_pathology, Уверенность: 61.98%
# Изображение: 100003EC_anon.png, Предсказанный класс: no_pathology, Уверенность: 92.07%
# Изображение: 100003ED_anon.png, Предсказанный класс: pathology, Уверенность: 50.98%
# Изображение: 100003EE_anon.png, Предсказанный класс: no_pathology, Уверенность: 83.40%
# Изображение: 100003EF_anon.png, Предсказанный класс: no_pathology, Уверенность: 76.06%
# Изображение: 100003F0_anon.png, Предсказанный класс: no_pathology, Уверенность: 89.15%
# Изображение: 100003F1_anon.png, Предсказанный класс: no_pathology, Уверенность: 81.65%
# Изображение: 100003F2_anon.png, Предсказанный класс: no_pathology, Уверенность: 76.17%
# Изображение: 100003F3_anon.png, Предсказанный класс: no_pathology, Уверенность: 89.32%
# Изображение: 100003F4_anon.png, Предсказанный класс: no_pathology, Уверенность: 91.89%
# Изображение: 100003F5_anon.png, Предсказанный класс: no_pathology, Уверенность: 95.61%
# Изображение: 100003F6_anon.png, Предсказанный класс: no_pathology, Уверенность: 97.42%
# Изображение: 100003F7_anon.png, Предсказанный класс: no_pathology, Уверенность: 84.70%
# Изображение: 100003F8_anon.png, Предсказанный класс: no_pathology, Уверенность: 90.15%
# Изображение: 100003F9_anon.png, Предсказанный класс: no_pathology, Уверенность: 86.76%
# Изображение: 100003FA_anon.png, Предсказанный класс: no_pathology, Уверенность: 90.22%
# Изображение: 100003FB_anon.png, Предсказанный класс: no_pathology, Уверенность: 90.37%
# Изображение: 100003FC_anon.png, Предсказанный класс: no_pathology, Уверенность: 84.54%
# Изображение: 100003FD_anon.png, Предсказанный класс: no_pathology, Уверенность: 93.98%
# Изображение: 100003FE_anon.png, Предсказанный класс: no_pathology, Уверенность: 95.99%
# Изображение: 100003FF_anon.png, Предсказанный класс: no_pathology, Уверенность: 73.54%
# Изображение: 10000400_anon.png, Предсказанный класс: no_pathology, Уверенность: 87.99%
# Изображение: 10000401_anon.png, Предсказанный класс: no_pathology, Уверенность: 89.21%
# Изображение: 10000402_anon.png, Предсказанный класс: no_pathology, Уверенность: 80.33%
# Изображение: 10000403_anon.png, Предсказанный класс: no_pathology, Уверенность: 78.52%
# Изображение: 10000404_anon.png, Предсказанный класс: no_pathology, Уверенность: 81.01%
# Изображение: 10000405_anon.png, Предсказанный класс: no_pathology, Уверенность: 83.50%
# Изображение: 10000406_anon.png, Предсказанный класс: no_pathology, Уверенность: 76.94%
# Изображение: 10000407_anon.png, Предсказанный класс: pathology, Уверенность: 77.81%
# Изображение: 10000408_anon.png, Предсказанный класс: pathology, Уверенность: 92.77%
# Изображение: 10000409_anon.png, Предсказанный класс: pathology, Уверенность: 98.74%
# Изображение: 1000040A_anon.png, Предсказанный класс: pathology, Уверенность: 85.75%
# Изображение: 1000040B_anon.png, Предсказанный класс: pathology, Уверенность: 73.74%
# Изображение: 1000040C_anon.png, Предсказанный класс: pathology, Уверенность: 70.31%
# Изображение: 1000040D_anon.png, Предсказанный класс: pathology, Уверенность: 90.34%
# Изображение: 1000040E_anon.png, Предсказанный класс: pathology, Уверенность: 81.49%
# Изображение: 1000040F_anon.png, Предсказанный класс: pathology, Уверенность: 88.89%
# Изображение: 10000410_anon.png, Предсказанный класс: pathology, Уверенность: 98.88%
# Изображение: 10000411_anon.png, Предсказанный класс: pathology, Уверенность: 99.87%
# Изображение: 10000412_anon.png, Предсказанный класс: pathology, Уверенность: 98.50%
# Изображение: 10000413_anon.png, Предсказанный класс: pathology, Уверенность: 99.39%
# Изображение: 10000414_anon.png, Предсказанный класс: pathology, Уверенность: 98.88%
# Изображение: 10000415_anon.png, Предсказанный класс: pathology, Уверенность: 99.20%
# Изображение: 10000416_anon.png, Предсказанный класс: pathology, Уверенность: 99.60%
# Изображение: 10000417_anon.png, Предсказанный класс: pathology, Уверенность: 98.51%
# Изображение: 10000418_anon.png, Предсказанный класс: pathology, Уверенность: 99.78%
# Изображение: 10000419_anon.png, Предсказанный класс: pathology, Уверенность: 99.27%
# Изображение: 1000041A_anon.png, Предсказанный класс: pathology, Уверенность: 98.99%
# Изображение: 1000041B_anon.png, Предсказанный класс: pathology, Уверенность: 98.87%
# Изображение: 1000041C_anon.png, Предсказанный класс: pathology, Уверенность: 98.82%
# Изображение: 1000041D_anon.png, Предсказанный класс: pathology, Уверенность: 99.96%
# Изображение: 1000041E_anon.png, Предсказанный класс: pathology, Уверенность: 99.80%
# Изображение: 1000041F_anon.png, Предсказанный класс: pathology, Уверенность: 99.97%
# Изображение: 10000420_anon.png, Предсказанный класс: pathology, Уверенность: 99.99%
# Изображение: 10000421_anon.png, Предсказанный класс: pathology, Уверенность: 99.99%
# Изображение: 10000422_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000423_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000424_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000425_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000426_anon.png, Предсказанный класс: pathology, Уверенность: 99.99%
# Изображение: 10000427_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000428_anon.png, Предсказанный класс: pathology, Уверенность: 99.96%
# Изображение: 10000429_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000042A_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000042B_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000042C_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000042D_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000042E_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000042F_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000430_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000431_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000432_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000433_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000434_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000435_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000436_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000437_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000438_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000439_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000043A_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000043B_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000043C_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000043D_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000043E_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000043F_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000440_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000441_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000442_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000443_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000444_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000445_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000446_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000447_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000448_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000449_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000044A_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000044B_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000044C_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000044D_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000044E_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 1000044F_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000450_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000451_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000452_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000453_anon.png, Предсказанный класс: pathology, Уверенность: 100.00%
# Изображение: 10000454_anon.png, Предсказанный класс: pathology, Уверенность: 99.97%
# Изображение: 10000455_anon.png, Предсказанный класс: pathology, Уверенность: 99.94%
# Изображение: 10000456_anon.png, Предсказанный класс: pathology, Уверенность: 99.97%
# Изображение: 10000457_anon.png, Предсказанный класс: pathology, Уверенность: 99.99%
# Изображение: 10000458_anon.png, Предсказанный класс: pathology, Уверенность: 99.97%
# Изображение: 10000459_anon.png, Предсказанный класс: pathology, Уверенность: 99.97%
# Изображение: 1000045A_anon.png, Предсказанный класс: pathology, Уверенность: 99.88%
# Изображение: 1000045B_anon.png, Предсказанный класс: pathology, Уверенность: 99.90%
# Изображение: 1000045C_anon.png, Предсказанный класс: pathology, Уверенность: 99.93%
# Изображение: 1000045D_anon.png, Предсказанный класс: pathology, Уверенность: 99.93%
# Изображение: 1000045E_anon.png, Предсказанный класс: pathology, Уверенность: 99.98%
# Изображение: 1000045F_anon.png, Предсказанный класс: pathology, Уверенность: 99.98%
# Изображение: 10000460_anon.png, Предсказанный класс: pathology, Уверенность: 99.94%
# Изображение: 10000461_anon.png, Предсказанный класс: pathology, Уверенность: 99.96%
# Изображение: 10000462_anon.png, Предсказанный класс: pathology, Уверенность: 99.86%
# Изображение: 10000463_anon.png, Предсказанный класс: pathology, Уверенность: 99.97%
# Изображение: 10000464_anon.png, Предсказанный класс: pathology, Уверенность: 99.96%
# Изображение: 10000465_anon.png, Предсказанный класс: pathology, Уверенность: 99.98%
# Изображение: 10000466_anon.png, Предсказанный класс: pathology, Уверенность: 99.99%
# Изображение: 10000467_anon.png, Предсказанный класс: pathology, Уверенность: 99.98%
# Изображение: 10000468_anon.png, Предсказанный класс: pathology, Уверенность: 99.99%
# Изображение: 10000469_anon.png, Предсказанный класс: pathology, Уверенность: 99.93%
# Изображение: 1000046A_anon.png, Предсказанный класс: pathology, Уверенность: 99.88%
# Изображение: 1000046B_anon.png, Предсказанный класс: pathology, Уверенность: 98.96%
# Изображение: 1000046C_anon.png, Предсказанный класс: pathology, Уверенность: 99.31%
# Изображение: 1000046D_anon.png, Предсказанный класс: pathology, Уверенность: 99.43%
# Изображение: 1000046E_anon.png, Предсказанный класс: pathology, Уверенность: 99.18%
# Изображение: 1000046F_anon.png, Предсказанный класс: pathology, Уверенность: 99.61%
# Изображение: 10000470_anon.png, Предсказанный класс: pathology, Уверенность: 98.72%
# Изображение: 10000471_anon.png, Предсказанный класс: pathology, Уверенность: 95.80%
# Изображение: 10000472_anon.png, Предсказанный класс: pathology, Уверенность: 99.21%
# Изображение: 10000473_anon.png, Предсказанный класс: pathology, Уверенность: 95.28%
# Изображение: 10000474_anon.png, Предсказанный класс: pathology, Уверенность: 97.23%
# Изображение: 10000475_anon.png, Предсказанный класс: pathology, Уверенность: 91.38%
# Изображение: 10000476_anon.png, Предсказанный класс: pathology, Уверенность: 92.33%
# Изображение: 10000477_anon.png, Предсказанный класс: pathology, Уверенность: 94.40%
# Изображение: 10000478_anon.png, Предсказанный класс: pathology, Уверенность: 92.45%
# Изображение: 10000479_anon.png, Предсказанный класс: pathology, Уверенность: 90.38%
# Изображение: 1000047A_anon.png, Предсказанный класс: pathology, Уверенность: 59.06%
# Изображение: 1000047B_anon.png, Предсказанный класс: pathology, Уверенность: 66.11%
# Изображение: 1000047C_anon.png, Предсказанный класс: pathology, Уверенность: 85.70%
# Изображение: 1000047D_anon.png, Предсказанный класс: pathology, Уверенность: 78.34%
# Изображение: 1000047E_anon.png, Предсказанный класс: pathology, Уверенность: 97.64%
# Изображение: 1000047F_anon.png, Предсказанный класс: pathology, Уверенность: 89.33%
# Изображение: 10000480_anon.png, Предсказанный класс: pathology, Уверенность: 97.47%
# Изображение: 10000481_anon.png, Предсказанный класс: pathology, Уверенность: 95.65%
# Изображение: 10000482_anon.png, Предсказанный класс: pathology, Уверенность: 99.18%
# Изображение: 10000483_anon.png, Предсказанный класс: pathology, Уверенность: 99.72%
# Изображение: 10000484_anon.png, Предсказанный класс: pathology, Уверенность: 98.28%
# Изображение: 10000485_anon.png, Предсказанный класс: pathology, Уверенность: 99.82%
# Изображение: 10000486_anon.png, Предсказанный класс: pathology, Уверенность: 99.83%
# Изображение: 10000487_anon.png, Предсказанный класс: pathology, Уверенность: 98.99%
# Изображение: 10000488_anon.png, Предсказанный класс: pathology, Уверенность: 99.46%
# Изображение: 10000489_anon.png, Предсказанный класс: pathology, Уверенность: 99.93%
# Изображение: 1000048A_anon.png, Предсказанный класс: pathology, Уверенность: 99.73%
# Изображение: 1000048B_anon.png, Предсказанный класс: pathology, Уверенность: 99.68%
# Изображение: 1000048C_anon.png, Предсказанный класс: pathology, Уверенность: 98.46%
# Изображение: 1000048D_anon.png, Предсказанный класс: pathology, Уверенность: 99.44%
# Изображение: 1000048E_anon.png, Предсказанный класс: pathology, Уверенность: 99.43%
# Изображение: 1000048F_anon.png, Предсказанный класс: pathology, Уверенность: 99.89%
# Изображение: 10000490_anon.png, Предсказанный класс: pathology, Уверенность: 99.91%
# Изображение: 10000491_anon.png, Предсказанный класс: pathology, Уверенность: 99.55%
# Изображение: 10000492_anon.png, Предсказанный класс: pathology, Уверенность: 99.49%
# Изображение: 10000493_anon.png, Предсказанный класс: pathology, Уверенность: 99.54%
# Изображение: 10000494_anon.png, Предсказанный класс: pathology, Уверенность: 99.84%
# Изображение: 10000495_anon.png, Предсказанный класс: pathology, Уверенность: 99.80%
# Изображение: 10000496_anon.png, Предсказанный класс: pathology, Уверенность: 99.97%
# Изображение: 10000497_anon.png, Предсказанный класс: pathology, Уверенность: 99.96%
# Изображение: 10000498_anon.png, Предсказанный класс: pathology, Уверенность: 99.90%
#
# --- Результаты классификации ---
# Всего обработано изображений: 367
# Изображений с патологией: 304
# Изображений без патологии: 63
# Средняя уверенность для класса 'pathology': 95.00%
# Средняя уверенность для класса 'no_pathology': 80.44%
